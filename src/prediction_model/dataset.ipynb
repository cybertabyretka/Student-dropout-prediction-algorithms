# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
path_2023_xlsx = '../../data/datasets/2023.xlsx'
path_2023_csv = '../../data/datasets/2023.csv'
path_2024_xlsx = '../../data/datasets/2024.xlsx'
path_2024_csv = '../../data/datasets/2024.csv'
path_2024_scores_1_csv = '../../data/datasets/2024_scores_1.csv'
path_2024_scores_2_csv = '../../data/datasets/2024_scores_2.csv'

# %%
data_2024_csv = pd.read_csv(path_2024_csv, delimiter=';', low_memory=False)
data_2023_csv = pd.read_csv(path_2023_csv, delimiter=';', low_memory=False)
data_2024_scores_1_csv = pd.read_csv(path_2024_scores_1_csv, delimiter=';')
data_2024_scores_2_csv = pd.read_csv(path_2024_scores_2_csv, delimiter=';')

# %%
data_2024_csv.head()
# Out:
#          UUID заявления абитуриента                  UUID абитуриента  \
# 0  corebo18je0480000p0d78noftfdp7to  entran18je0480000p0d78nobtrlu7nc
# 1  corebo18je0480000p0d78noftfdp7to  entran18je0480000p0d78nobtrlu7nc
# 2  corebo18je0480000p0d78noftfdp7to  entran18je0480000p0d78nobtrlu7nc
# 3  corebo18je0480000p0d78noftfdp7to  entran18je0480000p0d78nobtrlu7nc
# 4  corebo18je0480000p0d78noftfdp7to  entran18je0480000p0d78nobtrlu7nc
#
#                       UUID студента         UUID образ. прогр. (абит)  \
# 0  studen195e3pg0000p2siameff2oik1s  pstcim18hc2k00000m7in63pbgv4v6ls
# 1  studen195e3pg0000p2siameff2oik1s  pstcim18hc2k00000m7in63pbgv4v6ls
# 2  studen195e3pg0000p2siameff2oik1s  pstcim18hc2k00000m7in63pbgv4v6ls
# 3  studen195e3pg0000p2siameff2oik1s  pstcim18hc2k00000m7in63pbgv4v6ls
# 4  studen195e3pg0000p2siameff2oik1s  pstcim18hc2k00000m7in63pbgv4v6ls
#
#   Статус заявления абитуриента                UUID подразделения  \
# 0                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 1                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 2                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 3                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 4                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
#
#            UUID образ. прогр. (uni)  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  uncass18ggl5g0000kaou53o7bv2rs08          1                     105    0
# 1  uncass18ggl5g0000kaou53o7bv2rs08          1                     105    0
# 2  uncass18ggl5g0000kaou53o7bv2rs08          1                     105    0
# 3  uncass18ggl5g0000kaou53o7bv2rs08          1                     105    0
# 4  uncass18ggl5g0000kaou53o7bv2rs08          1                     105    0
#
#    ...  Город законченного уч. зав.          Тип законченного уч. зав.  \
# 0  ...                       Циньян  Средняя общеобразовательная школа
# 1  ...                       Циньян  Средняя общеобразовательная школа
# 2  ...                       Циньян  Средняя общеобразовательная школа
# 3  ...                       Циньян  Средняя общеобразовательная школа
# 4  ...                       Циньян  Средняя общеобразовательная школа
#
#   Название законченного уч. зав. Год окончание уч. зав.  \
# 0                    Школа Юнвэй                   2023
# 1                    Школа Юнвэй                   2023
# 2                    Школа Юнвэй                   2023
# 3                    Школа Юнвэй                   2023
# 4                    Школа Юнвэй                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Аттестат о среднем (полном) общем образовании                      NaN
# 1  Аттестат о среднем (полном) общем образовании                      NaN
# 2  Аттестат о среднем (полном) общем образовании                      NaN
# 3  Аттестат о среднем (полном) общем образовании                      NaN
# 4  Аттестат о среднем (полном) общем образовании                      NaN
#
#   Специальность зак.уч.зав. Льготы  Документы подтв. льготы  \
# 0                       NaN    NaN                      NaN
# 1                       NaN    NaN                      NaN
# 2                       NaN    NaN                      NaN
# 3                       NaN    NaN                      NaN
# 4                       NaN    NaN                      NaN
#
#                ФИО хэш
# 0 -2157402433798527159
# 1 -2157402433798527159
# 2 -2157402433798527159
# 3 -2157402433798527159
# 4 -2157402433798527159
#
# [5 rows x 92 columns]

# %%
data_2023_csv.head()
# Out:
#          UUID заявления абитуриента                  UUID абитуриента  \
# 0  corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 1  corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 2  corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 3  corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 4  corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
#
#                       UUID студента         UUID образ. прогр. (абит)  \
# 0  studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 1  studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 2  studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 3  studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 4  studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
#
#   Статус заявления абитуриента                UUID подразделения  \
# 0                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 1                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 2                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 3                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 4                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
#
#            UUID образ. прогр. (uni)  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205    0
# 1  uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205    0
# 2  uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205    0
# 3  uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205    0
# 4  uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205    0
#
#    ...  Город законченного уч. зав. Тип законченного уч. зав.  \
# 0  ...                   не указано                   Колледж
# 1  ...                   не указано                   Колледж
# 2  ...                   не указано                   Колледж
# 3  ...                   не указано                   Колледж
# 4  ...                   не указано                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 1  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 2  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 3  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 4  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
# 1  Диплом о среднем профессиональном образовании                      NaN
# 2  Диплом о среднем профессиональном образовании                      NaN
# 3  Диплом о среднем профессиональном образовании                      NaN
# 4  Диплом о среднем профессиональном образовании                      NaN
#
#   Специальность зак.уч.зав.                                    Льготы  \
# 0                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 1                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 2                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 3                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 4                       NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы              ФИО хэш
# 0  31 Копия свидетельства о смерти матери -5731017850755872298
# 1  31 Копия свидетельства о смерти матери -5731017850755872298
# 2  31 Копия свидетельства о смерти матери -5731017850755872298
# 3  31 Копия свидетельства о смерти матери -5731017850755872298
# 4  31 Копия свидетельства о смерти матери -5731017850755872298
#
# [5 rows x 92 columns]

# %%
data_2024_scores_1_csv.head()
# Out:
#                      Названия строк  Максимум по полю Cумма баллов испытаний
# 0  entran18je0480000p0d78nobtrlu7nc                                      105
# 1  entran18je0480000p0d7ocv6emhmkvo                                      113
# 2  entran18je0480000p0d9a9s3eghmqo0                                      130
# 3  entran18je0480000p0e951qhgqa7m18                                      237
# 4  entran18je0480000p0e9aitfpc9jslk                                      157

# %%
data_2024_scores_2_csv.head()
# Out:
#                      Названия строк  Максимум по полю Cумма баллов испытаний  \
# 0  entran18je0480000p2k4vio6ejb8igc                                       79
# 1  entran18je0480000p29g19ck6b53c9c                                       80
# 2  entran18je0480000p0jp8t9sqmqqkcc                                       85
# 3  entran18je0480000p25l1jh9as93nbo                                       87
# 4  entran18je0480000p1p7lptaicqlalg                                       91
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  80-100  100-120  120-140  140-160  \
# 0         NaN         NaN         NaN     8.0      5.0     10.0     47.0
# 1         NaN         NaN         NaN  1363.0   1355.0   1350.0   1340.0
# 2         NaN         NaN         NaN     NaN      NaN      NaN      NaN
# 3         NaN         NaN         NaN     NaN      NaN      NaN      NaN
# 4         NaN         NaN         NaN     NaN      NaN      NaN      NaN
#
#    160-180  180-200  200-220  220-240  240-260  260-280  280-300
# 0     84.0    155.0    219.0    238.0    448.0    134.0     15.0
# 1   1293.0   1209.0   1054.0    835.0    597.0    149.0      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN

# %%
data_2024_csv.describe()
# Out:
#           Приоритет  Cумма баллов испытаний           БВИ  \
# count  47167.000000            47167.000000  47167.000000
# mean       1.615939              185.350563      0.028579
# std        1.143295               73.807721      0.166623
# min        1.000000                0.000000      0.000000
# 25%        1.000000              135.000000      0.000000
# 50%        1.000000              214.000000      0.000000
# 75%        2.000000              244.000000      0.000000
# max        8.000000              294.000000      1.000000
#
#        Балл за инд. достижения  Оценка дифференцированная          Балл  \
# count             19143.000000               15929.000000  39042.000000
# mean                  5.882934                   3.802122     62.249372
# std                   2.859642                   1.112187     32.189227
# min                   1.000000                   2.000000      0.000000
# 25%                   3.000000                   3.000000     49.000000
# 50%                   5.000000                   4.000000     72.000000
# 75%                   9.000000                   5.000000     86.000000
# max                  10.000000                   5.000000    100.000000
#
#        Сквозной семестр           Год   ЛН студента  ЛН студента (архив)  \
# count      47167.000000  47167.000000  4.716700e+04                  0.0
# mean           1.006551   2023.996502  9.406438e+06                  NaN
# std            0.133212      0.070799  1.886893e+04                  NaN
# min            1.000000   2022.000000  9.204650e+06                  NaN
# 25%            1.000000   2024.000000  9.401701e+06                  NaN
# 50%            1.000000   2024.000000  9.403725e+06                  NaN
# 75%            1.000000   2024.000000  9.406120e+06                  NaN
# max            5.000000   2024.000000  9.499919e+06                  NaN
#
#        Год начала обучения  Срок освоения  Год окончания планируемый  \
# count         47167.000000   47167.000000               47167.000000
# mean           2023.993979       3.731592                2027.725571
# std               0.102578       1.065568                   1.068983
# min            2022.000000       2.000000                2026.000000
# 25%            2024.000000       4.000000                2028.000000
# 50%            2024.000000       4.000000                2028.000000
# 75%            2024.000000       4.000000                2028.000000
# max            2024.000000       6.000000                2030.000000
#
#        Вид договора на возм. затр.          Курс  Год окончание уч. зав.  \
# count                          0.0  47167.000000            47167.000000
# mean                           NaN      1.006021             2023.442831
# std                            NaN      0.102578                2.275438
# min                            NaN      1.000000             1993.000000
# 25%                            NaN      1.000000             2024.000000
# 50%                            NaN      1.000000             2024.000000
# 75%                            NaN      1.000000             2024.000000
# max                            NaN      3.000000             2024.000000
#
#             ФИО хэш
# count  4.716700e+04
# mean  -3.735044e+14
# std    5.273822e+18
# min   -9.221291e+18
# 25%   -4.552082e+18
# 50%    2.781776e+16
# 75%    4.443816e+18
# max    9.220102e+18

# %%
data_2024_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47167 entries, 0 to 47166
# Data columns (total 92 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   UUID заявления абитуриента       47167 non-null  object
#  1   UUID абитуриента                 47167 non-null  object
#  2   UUID студента                    47167 non-null  object
#  3   UUID образ. прогр. (абит)        47167 non-null  object
#  4   Статус заявления абитуриента     47167 non-null  object
#  5   UUID подразделения               47167 non-null  object
#  6   UUID образ. прогр. (uni)         47167 non-null  object
#  7   Приоритет                        47167 non-null  int64
#  8   Cумма баллов испытаний           47167 non-null  int64
#  9   БВИ                              47167 non-null  int64
#  10  Балл за инд. достижения          19143 non-null  float64
#  11  Вид конкурса                     47167 non-null  object
#  12  Наименование олимпиады           318 non-null    object
#  13  Тип олимпиады                    318 non-null    object
#  14  Категория конкурса БВИ           1348 non-null   object
#  15  UUID оценки                      47167 non-null  object
#  16  Контрольное мероприятие          47167 non-null  object
#  17  UUID группы                      47167 non-null  object
#  18  Оценка дифференцированная        15929 non-null  float64
#  19  Тип оценки                       47167 non-null  object
#  20  UUID нагрузки                    47167 non-null  object
#  21  Наименование дисциплины          47167 non-null  object
#  22  Модель реализации                47167 non-null  object
#  23  Оценка                           47167 non-null  object
#  24  Балл                             39042 non-null  float64
#  25  UUID Ведомости                   23605 non-null  object
#  26  Дата получения оценки            47167 non-null  object
#  27  Дата сдачи в ведомости           23562 non-null  object
#  28  Семестр                          47167 non-null  object
#  29  Сквозной семестр                 47167 non-null  int64
#  30  Год                              47167 non-null  int64
#  31  Наименование дисциплины ИТС      26865 non-null  object
#  32  ИТС наименование в дипломе       47167 non-null  object
#  33  UUID направления подготовки      47167 non-null  object
#  34  Код направления подготовки       47167 non-null  object
#  35  Наименование напр. подготовки    47167 non-null  object
#  36  UUID образовательной программы   47167 non-null  object
#  37  Код образовательной программы    47167 non-null  object
#  38  Образовательная программа        47167 non-null  object
#  39  ЛН студента                      47167 non-null  int64
#  40  ЛН студента (архив)              0 non-null      float64
#  41  Основа освоения                  47167 non-null  object
#  42  Основа освоения (сокр.)          47167 non-null  object
#  43  Форма освоения                   47167 non-null  object
#  44  UUID формирующего подразделения  47167 non-null  object
#  45  Формирующее подразделение        47167 non-null  object
#  46  UUID форм. подр. (Инст.)         47167 non-null  object
#  47  Форм. подр. (Инст.)              47167 non-null  object
#  48  Наименование группы              47167 non-null  object
#  49  Год начала обучения              47167 non-null  int64
#  50  Срок освоения                    47167 non-null  int64
#  51  Год окончания планируемый        47167 non-null  int64
#  52  Уровень подготовки               47167 non-null  object
#  53  UUID УГН                         47167 non-null  object
#  54  Код УГН                          47167 non-null  object
#  55  UUID Области образования         47167 non-null  object
#  56  Область образования              47167 non-null  object
#  57  Целевик                          47167 non-null  object
#  58  Хоз. группа | Вкл. обучение      47167 non-null  object
#  59  Нуждается в общежитии            47167 non-null  object
#  60  Малоимущий                       47167 non-null  object
#  61  Слушатель                        47167 non-null  object
#  62  Иностранный абитуриент (МОН)     47167 non-null  object
#  63  Вид договора на возм. затр.      0 non-null      float64
#  64  Курс                             47167 non-null  int64
#  65  Продолжил обучение               16 non-null     object
#  66  Состояние студента               47167 non-null  object
#  67  Активное состояние               47167 non-null  object
#  68  В архиве                         47167 non-null  object
#  69  Приказ об отчислении             47167 non-null  object
#  70  Акад. отп. по сост. здор.        47167 non-null  object
#  71  Акад. отп. по уходу за реб.      47167 non-null  object
#  72  UUID персоны                     47167 non-null  object
#  73  Пол                              47167 non-null  object
#  74  Дата рождения                    47167 non-null  object
#  75  Место рождения                   47167 non-null  object
#  76  Гражданство                      47167 non-null  object
#  77  Адрес регистрации. Страна        47167 non-null  object
#  78  Адрес регистрации. Область       45770 non-null  object
#  79  Адрес регистрации. Город         47167 non-null  object
#  80  Страна законченного уч. зав.     36405 non-null  object
#  81  Регион законченного уч. зав.     35071 non-null  object
#  82  Город законченного уч. зав.      36405 non-null  object
#  83  Тип законченного уч. зав.        47167 non-null  object
#  84  Название законченного уч. зав.   45308 non-null  object
#  85  Год окончание уч. зав.           47167 non-null  int64
#  86  Тип документа об образовании     47167 non-null  object
#  87  Квалификация зак.уч.зав.         11305 non-null  object
#  88  Специальность зак.уч.зав.        12266 non-null  object
#  89  Льготы                           2381 non-null   object
#  90  Документы подтв. льготы          2345 non-null   object
#  91  ФИО хэш                          47167 non-null  int64
# dtypes: float64(5), int64(12), object(75)
# memory usage: 33.1+ MB

# %%
def get_num_cat_columns(df):
    numeric_columns = df.select_dtypes(include=[np.int64, np.float64]).columns.tolist()
    categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()
    return numeric_columns, categorical_columns

# %%
num_cols_2024, cat_cols_2024 = get_num_cat_columns(data_2024_csv)
num_cols_2023, cat_cols_2023 = get_num_cat_columns(data_2023_csv)

# %%
print(num_cols_2024)
print(cat_cols_2024)
print("-"*144)
print(num_cols_2023)
print(cat_cols_2023)
# Out:
# ['Приоритет', 'Cумма баллов испытаний', 'БВИ', 'Балл за инд. достижения', 'Оценка дифференцированная', 'Балл', 'Сквозной семестр', 'Год', 'ЛН студента', 'ЛН студента (архив)', 'Год начала обучения', 'Срок освоения', 'Год окончания планируемый', 'Вид договора на возм. затр.', 'Курс', 'Год окончание уч. зав.', 'ФИО хэш']
# ['UUID заявления абитуриента', 'UUID абитуриента', 'UUID студента', 'UUID образ. прогр. (абит)', 'Статус заявления абитуриента', 'UUID подразделения', 'UUID образ. прогр. (uni)', 'Вид конкурса', 'Наименование олимпиады', 'Тип олимпиады', 'Категория конкурса БВИ', 'UUID оценки', 'Контрольное мероприятие', 'UUID группы', 'Тип оценки', 'UUID нагрузки', 'Наименование дисциплины', 'Модель реализации', 'Оценка', 'UUID Ведомости', 'Дата получения оценки', 'Дата сдачи в ведомости', 'Семестр', 'Наименование дисциплины ИТС', 'ИТС наименование в дипломе', 'UUID направления подготовки', 'Код направления подготовки', 'Наименование напр. подготовки', 'UUID образовательной программы', 'Код образовательной программы', 'Образовательная программа', 'Основа освоения', 'Основа освоения (сокр.)', 'Форма освоения', 'UUID формирующего подразделения', 'Формирующее подразделение', 'UUID форм. подр. (Инст.)', 'Форм. подр. (Инст.)', 'Наименование группы', 'Уровень подготовки', 'UUID УГН', 'Код УГН', 'UUID Области образования', 'Область образования', 'Целевик', 'Хоз. группа | Вкл. обучение', 'Нуждается в общежитии', 'Малоимущий', 'Слушатель', 'Иностранный абитуриент (МОН)', 'Продолжил обучение', 'Состояние студента', 'Активное состояние', 'В архиве', 'Приказ об отчислении', 'Акад. отп. по сост. здор.', 'Акад. отп. по уходу за реб.', 'UUID персоны', 'Пол', 'Дата рождения', 'Место рождения', 'Гражданство', 'Адрес регистрации. Страна', 'Адрес регистрации. Область', 'Адрес регистрации. Город', 'Страна законченного уч. зав.', 'Регион законченного уч. зав.', 'Город законченного уч. зав.', 'Тип законченного уч. зав.', 'Название законченного уч. зав.', 'Тип документа об образовании', 'Квалификация зак.уч.зав.', 'Специальность зак.уч.зав.', 'Льготы', 'Документы подтв. льготы']
# ------------------------------------------------------------------------------------------------------------------------------------------------
# ['Приоритет', 'Cумма баллов испытаний', 'БВИ', 'Балл за инд. достижения', 'Оценка дифференцированная', 'Балл', 'Сквозной семестр', 'Год', 'ЛН студента', 'ЛН студента (архив)', 'Год начала обучения', 'Срок освоения', 'Год окончания планируемый', 'Вид договора на возм. затр.', 'Курс', 'Год окончание уч. зав.', 'ФИО хэш']
# ['UUID заявления абитуриента', 'UUID абитуриента', 'UUID студента', 'UUID образ. прогр. (абит)', 'Статус заявления абитуриента', 'UUID подразделения', 'UUID образ. прогр. (uni)', 'Вид конкурса', 'Наименование олимпиады', 'Тип олимпиады', 'Категория конкурса БВИ', 'UUID оценки', 'Контрольное мероприятие', 'UUID группы', 'Тип оценки', 'UUID нагрузки', 'Наименование дисциплины', 'Модель реализации', 'Оценка', 'UUID Ведомости', 'Дата получения оценки', 'Дата сдачи в ведомости', 'Семестр', 'Наименование дисциплины ИТС', 'ИТС наименование в дипломе', 'UUID направления подготовки', 'Код направления подготовки', 'Наименование напр. подготовки', 'UUID образовательной программы', 'Код образовательной программы', 'Образовательная программа', 'Основа освоения', 'Основа освоения (сокр.)', 'Форма освоения', 'UUID формирующего подразделения', 'Формирующее подразделение', 'UUID форм. подр. (Инст.)', 'Форм. подр. (Инст.)', 'Наименование группы', 'Уровень подготовки', 'UUID УГН', 'Код УГН', 'UUID Области образования', 'Область образования', 'Целевик', 'Хоз. группа | Вкл. обучение', 'Нуждается в общежитии', 'Малоимущий', 'Слушатель', 'Иностранный абитуриент (МОН)', 'Продолжил обучение', 'Состояние студента', 'Активное состояние', 'В архиве', 'Приказ об отчислении', 'Акад. отп. по сост. здор.', 'Акад. отп. по уходу за реб.', 'UUID персоны', 'Пол', 'Дата рождения', 'Место рождения', 'Гражданство', 'Адрес регистрации. Страна', 'Адрес регистрации. Область', 'Адрес регистрации. Город', 'Страна законченного уч. зав.', 'Регион законченного уч. зав.', 'Город законченного уч. зав.', 'Тип законченного уч. зав.', 'Название законченного уч. зав.', 'Тип документа об образовании', 'Квалификация зак.уч.зав.', 'Специальность зак.уч.зав.', 'Льготы', 'Документы подтв. льготы']

# %%
print(data_2024_csv.columns.tolist() == data_2023_csv.columns.tolist())
# Out:
# True

# %%
nunique_by_student_2024 = data_2024_csv.groupby('UUID студента').nunique()
nunique_by_student_2024.to_csv("../../data/datasets/nunique_by_student_2024.csv")
nunique_by_student_2023 = data_2023_csv.groupby('UUID студента').nunique()
nunique_by_student_2023.to_csv("../../data/datasets/nunique_by_student_2023.csv")

# %%
nunique_by_person_2024 = data_2024_csv.groupby('UUID персоны').nunique()
nunique_by_person_2024.to_csv("../../data/datasets/nunique_by_person_2024.csv")
nunique_by_person_2023 = data_2023_csv.groupby('UUID персоны').nunique()
nunique_by_person_2023.to_csv("../../data/datasets/nunique_by_person_2023.csv")

# %%
uuid_columns = [col for col in data_2024_csv.columns if col.startswith("UUID") and col != "UUID студента"]
hash_columns = ["ФИО хэш"]

# %%
uuid_columns
# Out:
# ['UUID заявления абитуриента',
#  'UUID абитуриента',
#  'UUID образ. прогр. (абит)',
#  'UUID подразделения',
#  'UUID образ. прогр. (uni)',
#  'UUID оценки',
#  'UUID группы',
#  'UUID нагрузки',
#  'UUID Ведомости',
#  'UUID направления подготовки',
#  'UUID образовательной программы',
#  'UUID формирующего подразделения',
#  'UUID форм. подр. (Инст.)',
#  'UUID УГН',
#  'UUID Области образования',
#  'UUID персоны']

# %%
data_2024 = data_2024_csv.drop(columns=[*uuid_columns, *hash_columns])

# %%
data_2023_2024_csv = pd.concat([data_2023_csv, data_2024_csv], ignore_index=True)

# %%
data_2023_2024_csv
# Out:
#               UUID заявления абитуриента                  UUID абитуриента  \
# 0       corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 1       corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 2       corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 3       corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# 4       corebo18je0480000oifq05n6s0rgv94  entran18je0480000oifin39pb5b35o0
# ...                                  ...                               ...
# 178447  corebo18je0480000p1q3dq0u8ha3uuo  entran18je0480000p1q3dq0s4690hl4
# 178448  corebo18je0480000p1q3dq0u8ha3uuo  entran18je0480000p1q3dq0s4690hl4
# 178449  corebo18je0480000p1q3dq0u8ha3uuo  entran18je0480000p1q3dq0s4690hl4
# 178450  corebo18je0480000p1q3dq0u8ha3uuo  entran18je0480000p1q3dq0s4690hl4
# 178451  corebo18je0480000p1q3dq0u8ha3uuo  entran18je0480000p1q3dq0s4690hl4
#
#                            UUID студента         UUID образ. прогр. (абит)  \
# 0       studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 1       studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 2       studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 3       studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# 4       studen195e3pg0000ok22fnqsr14o7ek  pstcim18hc2k00000m5kl98deja3ha68
# ...                                  ...                               ...
# 178447  studen195e3pg0000p2uc7h4o5ah9uco  pstcim195e3rg0000o919g6ure7agets
# 178448  studen195e3pg0000p2uc7h4o5ah9uco  pstcim195e3rg0000o919g6ure7agets
# 178449  studen195e3pg0000p2uc7h4o5ah9uco  pstcim195e3rg0000o919g6ure7agets
# 178450  studen195e3pg0000p2uc7h4o5ah9uco  pstcim195e3rg0000o919g6ure7agets
# 178451  studen195e3pg0000p2uc7h4o5ah9uco  pstcim195e3rg0000o919g6ure7agets
#
#        Статус заявления абитуриента                UUID подразделения  \
# 0                          Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 1                          Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 2                          Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 3                          Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 4                          Зачислен  undifa18gg3ig0000glddlthn8j7k500
# ...                             ...                               ...
# 178447                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 178448                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 178449                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 178450                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
# 178451                     Зачислен  undifa18gg3ig0000glddlthn8j7k500
#
#                 UUID образ. прогр. (uni)  Приоритет  Cумма баллов испытаний  \
# 0       uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205
# 1       uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205
# 2       uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205
# 3       uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205
# 4       uncass18ggl5g0000l1j0nsj8ltvqpbo          1                     205
# ...                                  ...        ...                     ...
# 178447  uncass195e3pg0000mitlvmfbo4fqjcg          1                      86
# 178448  uncass195e3pg0000mitlvmfbo4fqjcg          1                      86
# 178449  uncass195e3pg0000mitlvmfbo4fqjcg          1                      86
# 178450  uncass195e3pg0000mitlvmfbo4fqjcg          1                      86
# 178451  uncass195e3pg0000mitlvmfbo4fqjcg          1                      86
#
#         БВИ  ...  Город законченного уч. зав. Тип законченного уч. зав.  \
# 0         0  ...                   не указано                   Колледж
# 1         0  ...                   не указано                   Колледж
# 2         0  ...                   не указано                   Колледж
# 3         0  ...                   не указано                   Колледж
# 4         0  ...                   не указано                   Колледж
# ...     ...  ...                          ...                       ...
# 178447    0  ...                          NaN                    Высшее
# 178448    0  ...                          NaN                    Высшее
# 178449    0  ...                          NaN                    Высшее
# 178450    0  ...                          NaN                    Высшее
# 178451    0  ...                          NaN                    Высшее
#
#                            Название законченного уч. зав.  \
# 0       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 1       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 2       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 3       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 4       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# ...                                                   ...
# 178447  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178448  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178449  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178450  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178451  ФГАОУ ВО УРФУ им. первого Президента России Б....
#
#        Год окончание уч. зав.                   Тип документа об образовании  \
# 0                        2023  Диплом о среднем профессиональном образовании
# 1                        2023  Диплом о среднем профессиональном образовании
# 2                        2023  Диплом о среднем профессиональном образовании
# 3                        2023  Диплом о среднем профессиональном образовании
# 4                        2023  Диплом о среднем профессиональном образовании
# ...                       ...                                            ...
# 178447                   2024                               Диплом бакалавра
# 178448                   2024                               Диплом бакалавра
# 178449                   2024                               Диплом бакалавра
# 178450                   2024                               Диплом бакалавра
# 178451                   2024                               Диплом бакалавра
#
#        Квалификация зак.уч.зав. Специальность зак.уч.зав.  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 178447                 бакалавр           43.03.01 Сервис
# 178448                 бакалавр           43.03.01 Сервис
# 178449                 бакалавр           43.03.01 Сервис
# 178450                 бакалавр           43.03.01 Сервис
# 178451                 бакалавр           43.03.01 Сервис
#
#                                           Льготы  \
# 0       02 Лица из числа детей-сирот (до 23 лет)
# 1       02 Лица из числа детей-сирот (до 23 лет)
# 2       02 Лица из числа детей-сирот (до 23 лет)
# 3       02 Лица из числа детей-сирот (до 23 лет)
# 4       02 Лица из числа детей-сирот (до 23 лет)
# ...                                          ...
# 178447                                       NaN
# 178448                                       NaN
# 178449                                       NaN
# 178450                                       NaN
# 178451                                       NaN
#
#                        Документы подтв. льготы              ФИО хэш
# 0       31 Копия свидетельства о смерти матери -5731017850755872298
# 1       31 Копия свидетельства о смерти матери -5731017850755872298
# 2       31 Копия свидетельства о смерти матери -5731017850755872298
# 3       31 Копия свидетельства о смерти матери -5731017850755872298
# 4       31 Копия свидетельства о смерти матери -5731017850755872298
# ...                                        ...                  ...
# 178447                                     NaN -2628443231091157700
# 178448                                     NaN -2628443231091157700
# 178449                                     NaN -2628443231091157700
# 178450                                     NaN -2628443231091157700
# 178451                                     NaN -2628443231091157700
#
# [178452 rows x 92 columns]

# %%
data_2023_2024 = data_2023_2024_csv.drop(columns=[*uuid_columns, *hash_columns])
data_2023_2024.shape
# Out:
# (178452, 75)

# %%
nunique_by_student_2023_2024 = data_2023_2024.groupby('UUID студента').nunique()

# %%
col_name = "Контрольное мероприятие"
print(nunique_by_student_2023_2024[col_name].nunique())
print(nunique_by_student_2023_2024[col_name].unique())
# Out:
# 4
# [2 1 3 4]

# %%
data_2023_2024["UUID студента"].nunique()
# Out:
# 4528

# %%
data_2023_2024[
    (data_2023_2024["Курс"] == 1) & 
    (data_2023_2024["Формирующее подразделение"] == "Школа бакалавриата")
]["Наименование дисциплины"].nunique()
# Out:
# 52

# %%
lst = data_2023_2024_csv.columns.to_list()

# %%
new_2023_2024 = data_2023_2024[data_2023_2024["UUID студента"] == 'studen195e3pg0000ok228vcfcqfrncg']

# %%
new_2023_2024['Курс'].unique()
# Out:
# array([2])

# %%
ids_2 = data_2023_2024_csv[data_2023_2024_csv["Курс"] == 2]["UUID персоны"].unique()

# %%
ids_1 = data_2023_2024_csv[data_2023_2024_csv["Курс"] == 1]["UUID персоны"].unique()

# %%
for id in ids_2:
    if id in ids_1:
        print(id)

# %%
data_2023_2024_csv.shape
# Out:
# (178452, 92)

# %%
data_2023_2024_csv.to_csv('../../data/datasets/2023_2024.csv', sep=';', index=False, encoding='utf-8-sig')

# %%
def get_columns_to_delete(file_path):
    columns_to_delete = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            parts = line.split('-')
            if len(parts) == 2:
                column_name = parts[0].strip()
                flag = parts[1].strip()
                if flag == 'd':
                    columns_to_delete.append(column_name)
    return columns_to_delete

file_path = '../../data/datasets/dataset_0_description'

columns_to_delete = get_columns_to_delete(file_path)
columns_to_delete.remove("UUID Ведомости")

print("Столбцы для удаления:")
for column in columns_to_delete:
    print(column)
# Out:
# Столбцы для удаления:
# UUID заявления абитуриента
# UUID абитуриента
# UUID образ. прогр. (абит)
# Статус заявления абитуриента
# UUID подразделения
# UUID образ. прогр. (uni)
# UUID группы
# Оценка дифференцированная
# UUID нагрузки
# Дата сдачи в ведомости
# UUID направления подготовки
# UUID образовательной программы
# Код образовательной программы
# Основа освоения
# UUID формирующего подразделения
# UUID форм. подр. (Инст.)
# Форм. подр. (Инст.)
# Наименование группы
# Год окончания планируемый
# UUID УГН
# Код УГН
# UUID Области образования
# Вид договора на возм. затр.
# Продолжил обучение
# ФИО хэш

# %%
df = data_2023_2024_csv.drop(columns=columns_to_delete, axis=1)

# %%
df.shape
# Out:
# (178452, 67)

# %%
df
# Out:
#                            UUID студента  Приоритет  Cумма баллов испытаний  \
# 0       studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 1       studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 2       studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 3       studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 4       studen195e3pg0000ok22fnqsr14o7ek          1                     205
# ...                                  ...        ...                     ...
# 178447  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 178448  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 178449  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 178450  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 178451  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
#
#         БВИ  Балл за инд. достижения    Вид конкурса Наименование олимпиады  \
# 0         0                      NaN    Особая квота                    NaN
# 1         0                      NaN    Особая квота                    NaN
# 2         0                      NaN    Особая квота                    NaN
# 3         0                      NaN    Особая квота                    NaN
# 4         0                      NaN    Особая квота                    NaN
# ...     ...                      ...             ...                    ...
# 178447    0                     10.0  Основные места                    NaN
# 178448    0                     10.0  Основные места                    NaN
# 178449    0                     10.0  Основные места                    NaN
# 178450    0                     10.0  Основные места                    NaN
# 178451    0                     10.0  Основные места                    NaN
#
#        Тип олимпиады Категория конкурса БВИ                       UUID оценки  \
# 0                NaN                    NaN  qldflt195e3pg0000p0ojcks1r0brulk
# 1                NaN                    NaN  qldflt195e3pg0000p9a199s0tmd01fs
# 2                NaN                    NaN  qldflt195e3pg0000p9a1uimadbqc25o
# 3                NaN                    NaN  qldflt195e3pg0000p91r12floo1c7uc
# 4                NaN                    NaN  qldflt195e3pg0000p0970r8ioub3j9c
# ...              ...                    ...                               ...
# 178447           NaN                    NaN  qldflt195e3pg0000p90otfn7055sshs
# 178448           NaN                    NaN  qldflt195e3pg0000p90otfn7055sshk
# 178449           NaN                    NaN  qldflt195e3pg0000p9a0djuqmitmcpo
# 178450           NaN                    NaN  qldflt195e3pg0000p9a0djur3rgjp84
# 178451           NaN                    NaN  qldflt195e3pg0000p94ej09jgnhpr7c
#
#         ... Регион законченного уч. зав. Город законченного уч. зав.  \
# 0       ...                          NaN                  не указано
# 1       ...                          NaN                  не указано
# 2       ...                          NaN                  не указано
# 3       ...                          NaN                  не указано
# 4       ...                          NaN                  не указано
# ...     ...                          ...                         ...
# 178447  ...                          NaN                         NaN
# 178448  ...                          NaN                         NaN
# 178449  ...                          NaN                         NaN
# 178450  ...                          NaN                         NaN
# 178451  ...                          NaN                         NaN
#
#        Тип законченного уч. зав.  \
# 0                        Колледж
# 1                        Колледж
# 2                        Колледж
# 3                        Колледж
# 4                        Колледж
# ...                          ...
# 178447                    Высшее
# 178448                    Высшее
# 178449                    Высшее
# 178450                    Высшее
# 178451                    Высшее
#
#                            Название законченного уч. зав.  \
# 0       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 1       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 2       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 3       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 4       ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# ...                                                   ...
# 178447  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178448  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178449  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178450  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 178451  ФГАОУ ВО УРФУ им. первого Президента России Б....
#
#        Год окончание уч. зав.                   Тип документа об образовании  \
# 0                        2023  Диплом о среднем профессиональном образовании
# 1                        2023  Диплом о среднем профессиональном образовании
# 2                        2023  Диплом о среднем профессиональном образовании
# 3                        2023  Диплом о среднем профессиональном образовании
# 4                        2023  Диплом о среднем профессиональном образовании
# ...                       ...                                            ...
# 178447                   2024                               Диплом бакалавра
# 178448                   2024                               Диплом бакалавра
# 178449                   2024                               Диплом бакалавра
# 178450                   2024                               Диплом бакалавра
# 178451                   2024                               Диплом бакалавра
#
#        Квалификация зак.уч.зав. Специальность зак.уч.зав.  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 178447                 бакалавр           43.03.01 Сервис
# 178448                 бакалавр           43.03.01 Сервис
# 178449                 бакалавр           43.03.01 Сервис
# 178450                 бакалавр           43.03.01 Сервис
# 178451                 бакалавр           43.03.01 Сервис
#
#                                           Льготы  \
# 0       02 Лица из числа детей-сирот (до 23 лет)
# 1       02 Лица из числа детей-сирот (до 23 лет)
# 2       02 Лица из числа детей-сирот (до 23 лет)
# 3       02 Лица из числа детей-сирот (до 23 лет)
# 4       02 Лица из числа детей-сирот (до 23 лет)
# ...                                          ...
# 178447                                       NaN
# 178448                                       NaN
# 178449                                       NaN
# 178450                                       NaN
# 178451                                       NaN
#
#                        Документы подтв. льготы
# 0       31 Копия свидетельства о смерти матери
# 1       31 Копия свидетельства о смерти матери
# 2       31 Копия свидетельства о смерти матери
# 3       31 Копия свидетельства о смерти матери
# 4       31 Копия свидетельства о смерти матери
# ...                                        ...
# 178447                                     NaN
# 178448                                     NaN
# 178449                                     NaN
# 178450                                     NaN
# 178451                                     NaN
#
# [178452 rows x 67 columns]

# %%
df_1 = df.dropna(subset=["UUID Ведомости"], axis=0)
df_1 = df_1.drop(["UUID Ведомости"], axis=1)

# %%
df_1.shape
# Out:
# (91102, 66)

# %%
df_1.to_csv("../../data/datasets/dataset_1.csv", sep=';', index=False, encoding='utf-8-sig')

# %%
df_1 = pd.read_csv("../../data/datasets/dataset_1.csv", sep=';', encoding='utf-8-sig', low_memory=False)

# %%
df_1
# Out:
#                           UUID студента  Приоритет  Cумма баллов испытаний  \
# 0      studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 1      studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 2      studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 3      studen195e3pg0000ok22fnqsr14o7ek          1                     205
# 4      studen195e3pg0000ok22fnqsr14o7ek          1                     205
# ...                                 ...        ...                     ...
# 91097  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 91098  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 91099  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 91100  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
# 91101  studen195e3pg0000p2uc7h4o5ah9uco          1                      86
#
#        БВИ  Балл за инд. достижения    Вид конкурса Наименование олимпиады  \
# 0        0                      NaN    Особая квота                    NaN
# 1        0                      NaN    Особая квота                    NaN
# 2        0                      NaN    Особая квота                    NaN
# 3        0                      NaN    Особая квота                    NaN
# 4        0                      NaN    Особая квота                    NaN
# ...    ...                      ...             ...                    ...
# 91097    0                     10.0  Основные места                    NaN
# 91098    0                     10.0  Основные места                    NaN
# 91099    0                     10.0  Основные места                    NaN
# 91100    0                     10.0  Основные места                    NaN
# 91101    0                     10.0  Основные места                    NaN
#
#       Тип олимпиады Категория конкурса БВИ                       UUID оценки  \
# 0               NaN                    NaN  qldflt195e3pg0000p0ojcks1r0brulk
# 1               NaN                    NaN  qldflt195e3pg0000p9a199s0tmd01fs
# 2               NaN                    NaN  qldflt195e3pg0000p9a1uimadbqc25o
# 3               NaN                    NaN  qldflt195e3pg0000p91r12floo1c7uc
# 4               NaN                    NaN  qldflt195e3pg0000oqc4snbpauvougo
# ...             ...                    ...                               ...
# 91097           NaN                    NaN  qldflt195e3pg0000p8rfv18m778ah0g
# 91098           NaN                    NaN  qldflt195e3pg0000p8skf99oqph2eo4
# 91099           NaN                    NaN  qldflt195e3pg0000p9aq85r1ov51aps
# 91100           NaN                    NaN  qldflt195e3pg0000p90otfn7055sshs
# 91101           NaN                    NaN  qldflt195e3pg0000p9a0djur3rgjp84
#
#        ... Регион законченного уч. зав. Город законченного уч. зав.  \
# 0      ...                          NaN                  не указано
# 1      ...                          NaN                  не указано
# 2      ...                          NaN                  не указано
# 3      ...                          NaN                  не указано
# 4      ...                          NaN                  не указано
# ...    ...                          ...                         ...
# 91097  ...                          NaN                         NaN
# 91098  ...                          NaN                         NaN
# 91099  ...                          NaN                         NaN
# 91100  ...                          NaN                         NaN
# 91101  ...                          NaN                         NaN
#
#       Тип законченного уч. зав.  \
# 0                       Колледж
# 1                       Колледж
# 2                       Колледж
# 3                       Колледж
# 4                       Колледж
# ...                         ...
# 91097                    Высшее
# 91098                    Высшее
# 91099                    Высшее
# 91100                    Высшее
# 91101                    Высшее
#
#                           Название законченного уч. зав.  \
# 0      ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 1      ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 2      ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 3      ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# 4      ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...
# ...                                                  ...
# 91097  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 91098  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 91099  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 91100  ФГАОУ ВО УРФУ им. первого Президента России Б....
# 91101  ФГАОУ ВО УРФУ им. первого Президента России Б....
#
#       Год окончание уч. зав.                   Тип документа об образовании  \
# 0                       2023  Диплом о среднем профессиональном образовании
# 1                       2023  Диплом о среднем профессиональном образовании
# 2                       2023  Диплом о среднем профессиональном образовании
# 3                       2023  Диплом о среднем профессиональном образовании
# 4                       2023  Диплом о среднем профессиональном образовании
# ...                      ...                                            ...
# 91097                   2024                               Диплом бакалавра
# 91098                   2024                               Диплом бакалавра
# 91099                   2024                               Диплом бакалавра
# 91100                   2024                               Диплом бакалавра
# 91101                   2024                               Диплом бакалавра
#
#       Квалификация зак.уч.зав. Специальность зак.уч.зав.  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 91097                 бакалавр           43.03.01 Сервис
# 91098                 бакалавр           43.03.01 Сервис
# 91099                 бакалавр           43.03.01 Сервис
# 91100                 бакалавр           43.03.01 Сервис
# 91101                 бакалавр           43.03.01 Сервис
#
#                                          Льготы  \
# 0      02 Лица из числа детей-сирот (до 23 лет)
# 1      02 Лица из числа детей-сирот (до 23 лет)
# 2      02 Лица из числа детей-сирот (до 23 лет)
# 3      02 Лица из числа детей-сирот (до 23 лет)
# 4      02 Лица из числа детей-сирот (до 23 лет)
# ...                                         ...
# 91097                                       NaN
# 91098                                       NaN
# 91099                                       NaN
# 91100                                       NaN
# 91101                                       NaN
#
#                       Документы подтв. льготы
# 0      31 Копия свидетельства о смерти матери
# 1      31 Копия свидетельства о смерти матери
# 2      31 Копия свидетельства о смерти матери
# 3      31 Копия свидетельства о смерти матери
# 4      31 Копия свидетельства о смерти матери
# ...                                       ...
# 91097                                     NaN
# 91098                                     NaN
# 91099                                     NaN
# 91100                                     NaN
# 91101                                     NaN
#
# [91102 rows x 66 columns]

# %%
lst = df_1.columns.to_list()
mx_ln = max(len(x) for x in lst) + 1
nunique_df_1 = df_1.groupby("UUID студента").nunique()

lst = [s.strip() for s in lst]
lst.remove("UUID студента")

with open('../../data/datasets/dataset_1_description', 'w', encoding='utf-8') as f:
    for s in lst:
        ln_s = len(s)
        f.write(f'{s}')
        for _ in range(max(0, mx_ln - ln_s)):
            f.write(' ')
        f.write('- ')
        f.write(str(nunique_df_1[s].nunique()))
        if len(str(nunique_df_1[s].nunique())) == 1:
            f.write('  - ')
        else:
            f.write(' - ')
        f.write(str(nunique_df_1[s].unique()))
        f.write('\n')

# %%
nunique_df_1 = df_1.groupby("UUID студента").nunique()

# %%
for column in nunique_df_1.columns.to_list():
    print(f"{column} - {nunique_df_1[column].nunique()} - {nunique_df_1[column].unique()}")
# Out:
# Приоритет - 1 - [1]
# Cумма баллов испытаний - 1 - [1]
# БВИ - 1 - [1]
# Балл за инд. достижения - 2 - [1 0]
# Вид конкурса - 1 - [1]
# Наименование олимпиады - 2 - [0 1]
# Тип олимпиады - 2 - [0 1]
# Категория конкурса БВИ - 2 - [0 1]
# UUID оценки - 55 - [31 30 33 23 54 34 11 29 32 17 28 21 36 22  6 52 10 38 35 27 24 39  7 26
#  12 46 42 25 40 44 37 41 15 45 43 13  5 14 20 48 19  9 49  8  1 16 18 55
#  56 57 59 47  3 51  2]
# Контрольное мероприятие - 4 - [2 1 3 4]
# Тип оценки - 2 - [2 1]
# Наименование дисциплины - 36 - [24 18 38 11 22 12 16  6 10 28 21  7 23 35 30 20  5 36 27 15 14  9 19 13
#  26 17  8  1 32 50 34 33 25  3  2 45]
# Модель реализации - 4 - [4 3 2 1]
# Оценка - 9 - [6 8 4 5 3 7 2 1 9]
# Балл - 29 - [20 14 16 19 23 17 22 12  2 15 18 13  5 24  6 21  7  9  8 11  1 25  4  3
#  10 26  0 27 28]
# Дата получения оценки - 41 - [23 22 25 17 36 24  9 13 21 16 29 18  3 35 27  8 12 30 19 26 32  5 20  4
#  15  6 31 33 28 39 10 37  7 14 38 34 40 11 42  2  1]
# Семестр - 2 - [2 1]
# Сквозной семестр - 5 - [3 2 5 1 4]
# Год - 3 - [2 1 3]
# Наименование дисциплины ИТС - 23 - [19 15  9 20 11 14  6 17  4 22 13  8 10  5  3 23 16 12  1  0 18  7  2]
# ИТС наименование в дипломе - 2 - [2 1]
# Код направления подготовки - 1 - [1]
# Наименование напр. подготовки - 1 - [1]
# Образовательная программа - 1 - [1]
# ЛН студента - 2 - [1 0]
# ЛН студента (архив) - 2 - [0 1]
# Основа освоения (сокр.) - 1 - [1]
# Форма освоения - 1 - [1]
# Формирующее подразделение - 1 - [1]
# Год начала обучения - 1 - [1]
# Срок освоения - 1 - [1]
# Уровень подготовки - 1 - [1]
# Область образования - 1 - [1]
# Целевик - 1 - [1]
# Хоз. группа | Вкл. обучение - 1 - [1]
# Нуждается в общежитии - 1 - [1]
# Малоимущий - 1 - [1]
# Слушатель - 1 - [1]
# Иностранный абитуриент (МОН) - 1 - [1]
# Курс - 1 - [1]
# Состояние студента - 1 - [1]
# Активное состояние - 1 - [1]
# В архиве - 1 - [1]
# Приказ об отчислении - 1 - [1]
# Акад. отп. по сост. здор. - 1 - [1]
# Акад. отп. по уходу за реб. - 1 - [1]
# UUID персоны - 1 - [1]
# Пол - 1 - [1]
# Дата рождения - 1 - [1]
# Место рождения - 1 - [1]
# Гражданство - 1 - [1]
# Адрес регистрации. Страна - 1 - [1]
# Адрес регистрации. Область - 2 - [1 0]
# Адрес регистрации. Город - 1 - [1]
# Страна законченного уч. зав. - 2 - [1 0]
# Регион законченного уч. зав. - 2 - [0 1]
# Город законченного уч. зав. - 2 - [1 0]
# Тип законченного уч. зав. - 1 - [1]
# Название законченного уч. зав. - 2 - [1 0]
# Год окончание уч. зав. - 1 - [1]
# Тип документа об образовании - 1 - [1]
# Квалификация зак.уч.зав. - 2 - [0 1]
# Специальность зак.уч.зав. - 2 - [0 1]
# Льготы - 2 - [0 1]
# Документы подтв. льготы - 2 - [0 1]

# %%
lg_doc = {}

for lg, doc in df_1[['Льготы', 'Документы подтв. льготы']].itertuples(index=False):
    if lg not in lg_doc:
        lg_doc[lg] = set()
    lg_doc[lg].add(doc)
print(lg_doc)
# Out:
# {'02 Лица из числа детей-сирот (до 23 лет)': {nan, 'Иной документ', '31 Копия свидетельства о смерти матери', 'Решение суда о лишении обоих или единственного родителя родительских прав', 'Справка из органов социальной защиты', 'Свидетельство о рождении'}, nan: {nan}, '04 Дети-инвалиды': {'20 Копия справка учреждения медико-социальной экспертизы'}, '05 Лица из числа детей без попечения родителей (до 23 лет)': {nan, '12 Копия решения суда о лишении отца родительских прав', '16 Копия Свидетельства о рождении', '31 Копия свидетельства о смерти матери', 'Решение суда о лишении обоих или единственного родителя родительских прав', 'Справка из органов социальной защиты'}, '21 Дети военнослужащих, погибших или получивших увечье при исполнении обязанностей военной службы в специальной военной операции на территориях Украины': {'Документ, подтверждающий принадлежность к детям лиц, выполнявших задачи в связи с проведением СВО'}, '07 Инвалиды с детства': {'Документ, подтверждающий принадлежность к инвалидам с детства', '20 Копия справка учреждения медико-социальной экспертизы'}, '19 Дети лиц, принимавших участие в специальной военной операции на территориях Украины': {nan, 'Документ, подтверждающий принадлежность к детям лиц, выполнявших задачи в связи с проведением СВО'}, '17 Дети военнослужащих, сотрудников федеральных органов исполнительной власти и федеральных государственных органов, направленных в другие государства': {'Документ, подтверждающий принадлежность к детям военнослужащих, сотрудников ФОИВ, ФГО, ОВД РФ, направленных в другие государства и принимавших участие в боевых действиях'}, '11 Инвалиды II группы': {'Документ, подтверждающий принадлежность к инвалидам I и II групп', '20 Копия справка учреждения медико-социальной экспертизы'}, '10 Ветераны боевых действий': {'33 Копия удостоверения ветерана боевых действий'}, '03 Дети, оставшиеся без попечения родителей (до 18 лет)': {'12 Копия решения суда о лишении отца родительских прав'}, '09 Лица, поступающие по направлению Министерства в пределах квоты, установленной Правительством Российской Федерации': {'06 Направление Министерства науки и высшего образования Российской Федерации'}, 'Дети граждан, принимавших участие в СВО на территориях Украины, ДНР, ЛНР, Запорожской и Херсонской областей, погибших или получивших увечье': {'Документ, подтверждающий принадлежность к детям остальных граждан, проходящих (проходивших) военную службу, призванных на военную службу по мобилизации, заключивших контракт, при условии их участия в СВО, лиц, принимавших участие в боевых действиях со стороны ДНР, ЛНР', 'Документ, подтверждающий принадлежность к детям граждан, проходящих (проходивших) военную службу, призванных на военную службу по мобилизации, заключивших контракт, при условии их участия в СВО, лиц, принимавших участие в боевых действиях со стороны ДНР, ЛНР, если указанные граждане, лица, военнослужащие погибли или получили увечье (ранение, травму, контузию) в ходе СВО либо удостоены звания Героя Российской Федерации или награждены тремя орденами Мужества'}, 'Дети военнослужащих, сотрудников федеральных органов исполнительной власти и федеральных государственных органов, принимавших участие в боевых действиях в других государствах, погибших или получивших увечье': {'Документ, подтверждающий принадлежность к детям военнослужащих и сотрудников силовых ведомств, если эти военнослужащие, сотрудники погибли или получили увечье (ранение, травму, контузию) в ходе боевых действий в других государствах либо удостоены звания Героя Российской Федерации или награждены тремя орденами Мужества'}, 'Дети граждан, принимавших участие в СВО на территориях Украины, ДНР, ЛНР, Запорожской и Херсонской областей': {'Документ, подтверждающий принадлежность к детям остальных граждан, проходящих (проходивших) военную службу, призванных на военную службу по мобилизации, заключивших контракт, при условии их участия в СВО, лиц, принимавших участие в боевых действиях со стороны ДНР, ЛНР'}, 'Лица, поступающие по направл ...

# %%
pr_ba = {}
is_na = {'зач.': (70, 1), 'неуваж.': (0, 1), 'недсд.': (0, 1), '4': (70, 1), 'недоп.': (0, 1), '5': (90, 1), 'незач.': (20, 1), 'уваж.': (0, 0), '2': (20, 1), 'невбрн.': (0, 0), '3': (50, 1)}
s = set()

for index, row in df_1.iterrows():
    disc = row['Наименование дисциплины']
    score = row['Балл']
    oc = row['Оценка']

    if disc not in pr_ba:
        pr_ba[disc] = [0, 0]

    if pd.isna(score):
        pr_ba[disc][0] += is_na[oc][0]
        pr_ba[disc][1] += is_na[oc][1]
    else:
        pr_ba[disc][0] += score
        pr_ba[disc][1] += 1

    if pd.isna(score):
        s.add(oc)

print(pr_ba)
print(s)
# Out:
# {'Проектный практикум 1': [173985.0, 2432], 'Архитектура ЭВМ': [43428.0, 628], 'Анализ данных и искусственный интеллект': [54289.0, 777], 'Прикладная физическая культура': [352026.0, 5592], 'Введение в профессиональную деятельность': [57921.0, 744], 'Математика': [159806.0, 2946], 'Философия': [101723.0, 1469], 'Иностранный язык': [304796.0, 4559], 'История России': [201158.0, 3183], 'Векторный анализ': [83695.0, 1744], 'Программирование': [190529.0, 3301], 'Теория вероятностей и математическая статистика': [42723.0, 753], 'Основы проектной деятельности': [192776.0, 2768], 'Физика': [253639.0, 4423], 'Информационные технологии и сервисы': [186517.0, 2803], 'Основы российской государственности': [216535.0, 3170], 'Элементарные основы физики': [74055.0, 1161], 'Развитие ресурсов организма': [1563.0, 22], 'Основы личностного роста': [3085.0, 52], 'Web-технологии': [62389.0, 852], 'Введение в инженерную деятельность': [83200.0, 1202], 'Эффективные коммуникации': [86601.0, 1154], 'Современные языки программирования': [57960.0, 819], 'Дополнительные главы математики': [63260.0, 1239], 'Алгебра, геометрия и теория дифференциальных уравнений': [6594.0, 157], 'Дискретная математика и математическая логика': [4646.0, 86], 'Общевоинские уставы ВС РФ': [4477.0, 59], 'Математический анализ': [27250.0, 900], 'Информатика': [27417.0, 413], 'Теоретические основы электротехники': [1801.0, 44], 'Компоненты электронной техники': [1417.0, 38], 'Огневая подготовка из стрелкового оружия': [2424.0, 29], 'Материалы электронной техники': [1599.0, 44], 'Администрирование российских операционных систем': [3732.0, 48], 'Радиационная, химическая и биологическая защита': [2663.0, 29], 'Управление подразделениями в мирное время': [776.0, 14], 'Военная топография': [2420.0, 29], 'Введение в специальность': [56685.0, 814], 'Военная история': [1275.0, 15], 'Строевая подготовка': [4927.0, 59], 'Инженерная и компьютерная графика': [5122.0, 98], 'Численные методы': [938.0, 18], 'Физические основы электроники': [3404.0, 88], 'Основы интернета вещей': [3679.0, 72], 'Защита интеллектуальной собственности': [2167.0, 44], 'Алгоритмизация и программирование': [7828.0, 226], 'Электроника': [12775.0, 226], 'Основы теории цепей': [8583.0, 172], 'Проектный практикум 2': [54367.0, 815], 'Учебная практика, ознакомительная': [8703.0, 138], 'Компьютерная и инженерная графика': [18690.0, 405], 'Специальные главы математики': [9893.0, 314], 'Цифровые двойники в электронике, радиотехнике и системах связи': [2070.0, 35], 'Конструирование электромеханических устройств': [1625.0, 20], 'Учебная практика. ознакомительная': [2421.0, 41], 'Материалы электронных средств': [1396.0, 20], 'Дифференциальные уравнения и численные методы': [10469.0, 310], 'Основы информационной безопасности': [14472.0, 232], 'Теория информации': [8322.0, 97], 'Алгебра и геометрия': [23787.0, 437], 'Экономика и организация производства': [1144.0, 37], 'Языки программирования': [5507.0, 97], 'Схемотехника электронных устройств': [6087.0, 97], 'Теория массового обслуживания': [452.0, 6], 'Сбор и верификация данных': [7816.0, 136], 'Технологии программирования': [15565.0, 277], 'Алгоритмы и структуры данных': [2345.0, 33], 'Цифровые устройства': [2250.0, 43], 'Русский язык как иностранный (II уровень владения)': [982.0, 20], 'Электротехника': [1809.0, 57], 'Механика систем управления': [1261.0, 23], 'Микроконтроллеры': [1794.0, 23], 'Компьютерные и сетевые технологии в системах связи': [2313.0, 34], 'Алгебра': [21474.0, 355], 'Геометрия': [13165.0, 256], 'Экономика': [6510.0, 97], 'Финансы, денежное обращение и кредит': [3829.0, 52], 'Бухгалтерский учет': [3746.0, 51], 'Деньги, кредит, банки': [3520.0, 52], 'Компьютерное моделирование физических процессов и систем': [7076.0, 97], 'Языки и методы программирования': [4637.0, 98], 'Экспертная и аналитическая деятельность в сфере обеспечения безопасности объектов КИИ': [2400.0, 33], 'Меры и средства защиты информации от несанкционированного доступа в ИСПДн, ГИС и знач ...
# {'зач.', 'неуваж.', 'недсд.', '4', 'недоп.', '5', 'незач.', 'уваж.', '2', 'невбрн.', '3'}

# %%
df_1_2 = df_1[df_1['Оценка'] != 'уваж.']
df_1_2 = df_1_2[df_1_2["Оценка"] != "невбрн."]

# %%
df_1_2.shape
# Out:
# (81953, 66)

# %%
pr_ba = {}
is_na = {'зач.': (70, 1), 'неуваж.': (0, 1), 'недсд.': (0, 1), '4': (70, 1), 'недоп.': (0, 1), '5': (90, 1), 'незач.': (20, 1), '2': (20, 1), '3': (50, 1)}
s = set()

for index, row in df_1_2.iterrows():
    disc = row['Наименование дисциплины']
    score = row['Балл']
    oc = row['Оценка']

    if disc not in pr_ba:
        pr_ba[disc] = [0, 0, 0]

    if pd.isna(score):
        score = is_na[oc][0]
        pr_ba[disc][0] += is_na[oc][0]
        pr_ba[disc][1] += is_na[oc][1]
    else:
        pr_ba[disc][0] += score
        pr_ba[disc][1] += 1

    if int(score) == 0:
        pr_ba[disc][2] += 1
        
    if pd.isna(score):
        s.add(oc)

print(pr_ba)
print(s)
# Out:
# {'Проектный практикум 1': [173985.0, 2598, 349], 'Архитектура ЭВМ': [43428.0, 720, 176], 'Анализ данных и искусственный интеллект': [54289.0, 794, 130], 'Прикладная физическая культура': [352026.0, 6050, 1217], 'Введение в профессиональную деятельность': [57921.0, 757, 67], 'Математика': [159806.0, 3208, 638], 'Философия': [101723.0, 1629, 335], 'Иностранный язык': [304796.0, 4948, 853], 'История России': [201158.0, 3366, 565], 'Векторный анализ': [83695.0, 2049, 655], 'Программирование': [190529.0, 3394, 598], 'Теория вероятностей и математическая статистика': [42723.0, 830, 228], 'Основы проектной деятельности': [192776.0, 2964, 465], 'Физика': [253639.0, 4898, 964], 'Информационные технологии и сервисы': [186517.0, 3012, 611], 'Основы российской государственности': [216535.0, 3355, 476], 'Web-технологии': [62389.0, 878, 140], 'Введение в инженерную деятельность': [83200.0, 1363, 304], 'Эффективные коммуникации': [86601.0, 1175, 168], 'Современные языки программирования': [57960.0, 823, 145], 'Дополнительные главы математики': [63260.0, 1286, 211], 'Элементарные основы физики': [74055.0, 1422, 425], 'Развитие ресурсов организма': [1563.0, 31, 12], 'Основы личностного роста': [3085.0, 62, 20], 'Алгебра, геометрия и теория дифференциальных уравнений': [6594.0, 166, 26], 'Общевоинские уставы ВС РФ': [4477.0, 62, 3], 'Математический анализ': [27250.0, 992, 329], 'Информатика': [27417.0, 418, 30], 'Теоретические основы электротехники': [1801.0, 44, 4], 'Компоненты электронной техники': [1417.0, 44, 17], 'Огневая подготовка из стрелкового оружия': [2424.0, 29, 0], 'Материалы электронной техники': [1599.0, 44, 11], 'Администрирование российских операционных систем': [3732.0, 48, 1], 'Радиационная, химическая и биологическая защита': [2663.0, 29, 0], 'Управление подразделениями в мирное время': [776.0, 14, 4], 'Введение в специальность': [56685.0, 965, 228], 'Строевая подготовка': [4927.0, 62, 3], 'Инженерная и компьютерная графика': [5122.0, 100, 8], 'Военная топография': [2420.0, 29, 0], 'Физические основы электроники': [3404.0, 185, 133], 'Основы интернета вещей': [3679.0, 81, 12], 'Защита интеллектуальной собственности': [2167.0, 44, 15], 'Алгоритмизация и программирование': [7828.0, 292, 123], 'Электроника': [12775.0, 253, 65], 'Основы теории цепей': [8583.0, 175, 22], 'Проектный практикум 2': [54367.0, 842, 180], 'Учебная практика, ознакомительная': [8703.0, 145, 24], 'Компьютерная и инженерная графика': [18690.0, 516, 169], 'Специальные главы математики': [9893.0, 376, 205], 'Цифровые двойники в электронике, радиотехнике и системах связи': [2070.0, 140, 109], 'Конструирование электромеханических устройств': [1625.0, 20, 0], 'Учебная практика. ознакомительная': [2421.0, 41, 3], 'Материалы электронных средств': [1396.0, 20, 1], 'Дифференциальные уравнения и численные методы': [10469.0, 363, 127], 'Основы информационной безопасности': [14472.0, 241, 24], 'Теория информации': [8322.0, 100, 7], 'Алгебра и геометрия': [23787.0, 479, 85], 'Языки программирования': [5507.0, 99, 16], 'Схемотехника электронных устройств': [6087.0, 99, 15], 'Дискретная математика и математическая логика': [4646.0, 95, 16], 'Теория массового обслуживания': [452.0, 15, 9], 'Численные методы': [938.0, 19, 1], 'Сбор и верификация данных': [7816.0, 140, 20], 'Технологии программирования': [15565.0, 283, 51], 'Алгоритмы и структуры данных': [2345.0, 43, 10], 'Цифровые устройства': [2250.0, 43, 12], 'Военная история': [1275.0, 15, 0], 'Электротехника': [1809.0, 62, 27], 'Механика систем управления': [1261.0, 24, 1], 'Микроконтроллеры': [1794.0, 24, 1], 'Экономика и организация производства': [1144.0, 37, 24], 'Компьютерные и сетевые технологии в системах связи': [2313.0, 36, 4], 'Алгебра': [21474.0, 391, 60], 'Геометрия': [13165.0, 279, 40], 'Экономика': [6510.0, 99, 8], 'Финансы, денежное обращение и кредит': [3829.0, 53, 1], 'Бухгалтерский учет': [3746.0, 59, 8], 'Деньги, кредит, банки': [3520.0, 59, 7], 'Компьютерное моделирование физических процессов и сис ...
# set()

# %%
for key in pr_ba:
    if pr_ba[key][0] == 0:
        print(pr_ba[key])
# Out:
# [0, 7]
# [0.0, 1]
# [0, 5]
# [0, 4]
# [0, 4]
# [0, 4]
# [0, 2]
# [0, 1]
# [0, 3]
# [0, 3]
# [0, 1]
# [0.0, 1]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Определение функции
def f(x):
    return np.log(x)  # Натуральный логарифм ln(x)

# Создание массива значений x > 0
x = np.linspace(0.01, 10, 500)  # Диапазон от 0.01 до 10 (избегаем x <= 0)
y = f(x)

# Построение графика
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r"$f(x) = \ln(x)$", color="blue")
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')  # Горизонтальная ось
plt.axvline(1, color='red', linewidth=0.5, linestyle='--')   # Вертикальная линия через x=1
plt.title("График функции $f(x) = \ln(x)$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()

# %%
pr_ba_sorted = sorted(pr_ba, key=lambda x: x[1])

# %%
pr_ba_sorted = sorted(pr_ba.items(), key=lambda x: x[1][1])

# Вывод отсортированного списка
for key, value in pr_ba_sorted:
    print(f"{key}: {value}")
# Out:
# Активные процессы в современном русском языке: [71.0, 1, 0]
# Технические средства обработки информации: [0.0, 1, 1]
# Практика эффективной коммуникации: [43.0, 1, 0]
# Инновации и интеллектуальная собственность: [0, 1, 1]
# Русский язык как иностранный для начинающих англоговорящих студентов: [60.0, 1, 0]
# Программное обеспечение цифровой обработки сигналов: [0, 1, 1]
# Анализ естественного языка: [91.0, 1, 0]
# Учебная практика, технологическая (проектно-технологическая): [90.0, 1, 0]
# Выполнение и защита выпускной квалификационной работы: [55.0, 1, 0]
# Профессиональный курс. Спецкурс 1: [0.0, 1, 1]
# Профессиональный курс. Спецкурс 2: [55.0, 1, 0]
# Майнор 1: [89.0, 1, 0]
# Экономические и гуманитарные аспекты информационных технологий 2: [60.0, 1, 0]
# Базовая архитектура программного обеспечения: [49.0, 1, 0]
# Проектный практикум 4: [45.0, 1, 0]
# Правовые основы информационных технологий: [50.0, 1, 0]
# Организация инфокоммуникационных сетей: [0, 2, 2]
# Производственная практика, преддипломная: [70.0, 2, 1]
# Методы анализа и синтеза киберфизических и киберсоциальных систем: [40.0, 3, 2]
# Предметно-ориентированные языки и методы трансляции: [0, 3, 3]
# Курсы сетевого обмена: [0, 3, 3]
# Менеджмент качества при создании инновационных продуктов: [122.0, 3, 1]
# Управление движением подвижных объектов: [319.0, 4, 0]
# Математические методы построения программного обеспечения движения летательных объектов: [299.0, 4, 0]
# Проектирование бортовой аппаратуры систем управления: [200.0, 4, 1]
# Защита аппаратуры от внешних воздействующих факторов: [260.0, 4, 1]
# Проверочно-пусковая аппаратура систем управления ракетными комплексами: [272.0, 4, 1]
# Анализ алгоритмов: [103.0, 4, 1]
# Радиолокационные датчики интеллектуальных информационных систем: [0, 4, 4]
# Теория и техника радиолокации и радионавигации: [0, 4, 4]
# Радиоэлектронные системы дистанционного зондирования Земли: [0, 4, 4]
# Системы цифровой экономики: [60.0, 5, 3]
# Методы доступа к данным: [0, 5, 5]
# Теория решения изобретательских задач: [239.0, 5, 2]
# Оптимизация производственных и проектных решений: [431.0, 6, 1]
# Методы и средства научных исследований: [365.0, 6, 0]
# Разработка электронных изданий: [373.0, 6, 2]
# Современные технологии электрофотографии и струйной печати: [536.0, 6, 0]
# Проектирование печатных и послепечатных процессов: [380.0, 6, 1]
# Технологии цифровой фотосъемки: [276.0, 6, 2]
# Экономика инженерии: [510.0, 7, 1]
# Системная аналитика: [314.0, 7, 3]
# Практикум по цифровым компетенциям: [459.0, 7, 1]
# История: [0, 7, 7]
# Современные образовательные технологии: [321.0, 7, 3]
# Типографика и макетирование: [580.0, 7, 0]
# Безопасность жизнедеятельности: [62.0, 8, 7]
# Прикладное программирование: [480.0, 8, 1]
# Основы публичных выступлений: [136.0, 8, 6]
# Управление ИТ-проектами: [197.0, 8, 5]
# Естественнонаучное мировоззрение: [421.0, 9, 2]
# Биотехнические системы и технологии: [278.0, 9, 5]
# Разработка встраиваемых систем: [390.0, 9, 4]
# Интерфейсы мозг-компьютер: [317.0, 9, 5]
# Математическое моделирование и анализ данных в медицине и биологии: [396.0, 9, 4]
# Проектирование и применение цифровых инженерных решений в медицине и здравоохранении: [320.0, 9, 5]
# Теория цифровой обработки сигналов: [358.0, 9, 4]
# Введение в проблематику создания ракетных комплексов: [776.0, 10, 0]
# Методы и алгоритмы проектирования программного обеспечения систем управления: [726.0, 10, 0]
# Основы редактирования: [688.0, 11, 0]
# Язык делового общения: [701.0, 11, 0]
# Современный русский язык: [776.0, 12, 0]
# Стилистика русского языка: [823.0, 12, 0]
# Русский язык: [779.0, 12, 0]
# Практическая колориметрия и автотипия: [813.0, 12, 3]
# Управление подразделениями в мирное время: [776.0, 14, 4]
# Вычислительные системы реального времени: [280.0, 14, 8]
# Теория массового обслуживания: [452.0, 15, 9]
# Военная история: [1275.0, 15, 0]
# Компьютерный анализ и интерпретация данных: [217.0, 15, 10]
# Современные программно-инструментальные средства обработки сигналов и изображений: [1112.0, 15, 1]
# Автоматизированное проектирование средств и систем управления: [859.0, 15, 5]
# Технологии использования экспертных систем: [825.0, 15, 5]
# Современные интернет технологии: [486.0, 15, 9]
# Критическое мышление: [1053.0, 15, 2]
# Материалы микро- и наноэлектроники: [1162.0, 16, 2]
# Химия: [994.0, 16, 2]
# Разработка встроенных систем на программируемых логических интегральных схемах: [607.0, 17, 9]
# Построение отношений и влияние: [1100.0, 17, 6]
# Управление конфликтами: [1390.0, 18, 2]
# Публичные выступления: [1700.0, 18, 1]
# Численные методы: [938.0, 19, 1]
# Спецкурс по управлению в технических системах: [843.0, 19, 8]
# Корпоративные информационные системы: [1041.0, 19, 6]
# Электронный бизнес: [1408.0, 19, 2]
# Методы построения алгоритмов работы интеллектуальных систем управления: [894.0, 19, 7]
# Конструирование электромеханических устройств: [1625.0, 20, 0]
# Материалы электронных средств: [1396.0, 20, 1]
# Тематическая обработка радиолокационной информации: [249.0, 20, 17]
# Проектирование электронных устройств на базе цифровых сигнальных процессоров: [887.0, 20, 10]
# Управление в технических системах: [1158.0, 20, 7]
# Современные технологии моделирования систем связи: [470.0, 20, 13]
# Цифровые системы связи 4G и 5G: [703.0, 20, 10]
# Теория построения инфокоммуникационных сетей и систем: [510.0, 20, 14]
# Микроволновые антенны и антенные системы: [355.0, 21, 16]
# Проектирование цифровых интегральных микросхем и микропроцессоров: [1352.0, 22, 8]
# Проектирование компонентов и инфраструктурных систем интернета вещей: [279.0, 22, 19]
# Беспроводные сети нового поколения Wi-Fi 6: [279.0, 22, 19]
# Русский язык как иностранный (II уровень владения): [982.0, 22, 3]
# Автоматизированное проектирование высокочастотных устройств: [519.0, 22, 16]
# Радиофотоника: [423.0, 22, 16]
# Компьютерное многоуровневое моделирование радиоэлектронных средств: [421.0, 22, 15]
# Проектирование и организация технологических процессов: [1347.0, 22, 6]
# Оптимизация и архитектура систем управления: [1518.0, 22, 6]
# Графический дизайн: [1509.0, 22, 6]
# Машинное обучение и нейросетевое программирование: [1203.0, 22, 6]
# Цифровые фототехнологии: [1685.0, 22, 0]
# Программирование и обработка данных: [1382.0, 22, 0]
# Перспективные материалы репродукционных технологий: [1220.0, 22, 0]
# Web технологии в графических системах: [1380.0, 22, 6]
# Сенсорика для медицины: [1422.0, 22, 6]
# Разработка приложений на языке  PYTHON: [1181.0, 22, 7]
# Методы анализа данных и статистики: [1286.0, 22, 7]
# Здоровье человека и интеллектуальные информационные системы и технологии здоровьесбережения: [1246.0, 22, 6]
# Методы и аппаратно-программные комплексы функциональных исследований: [1123.0, 22, 8]
# Хранение и обработка данных: [866.0, 23, 10]
# Основы нейроинформатики и машинного обучения: [1130.0, 23, 9]
# Качество и надежность электрорадиоизделий и радиоэлектронной аппаратуры специального назначения: [915.0, 23, 8]
# Микро и нанотехнологии производства электронных средств: [915.0, 23, 8]
# Микроволновые устройства радиоэлектронных систем: [334.0, 23, 18]
# Микроволновая электроника: [436.0, 23, 18]
# Электромагнитная совместимость радиоэлектронных средств: [272.0, 23, 19]
# Механика систем управления: [1261.0, 24, 1]
# Микроконтроллеры: [1794.0, 24, 1]
# Искусственный интеллект и нейронные сети: [799.0, 24, 14]
# Проектирование радиотехнических систем: [627.0, 24, 16]
# Интеллектуальные информационные технологии проектирования электронных средств: [323.0, 24, 20]
# Проектирование высокочастотных средств: [317.0, 24, 19]
# Программно-аппаратные платформы Интернета вещей: [524.0, 24, 17]
# Спутниковые системы связи и навигации: [480.0, 24, 17]
# Основы обеспечения информационной безопасности: [1205.0, 25, 9]
# Обработка данных на языке Python: [533.0, 25, 17]
# Технические средства цифровой фототехники: [1616.0, 25, 6]
# Физические явления в репродукционных технологиях: [1339.0, 26, 10]
# Математическое моделирование: [1257.0, 26, 10]
# Психология обработки сенсорной информации: [1514.0, 26, 4]
# Виртуализация и облачные технологии: [675.0, 27, 17]
# Методы анализа и синтеза информационных систем: [626.0, 27, 17]
# Основы получения и предварительной обработки видеоизображений: [570.0, 27, 16]
# Разработка цифровых двойников: [904.0, 27, 16]
# Системы интеллектуальной обработки видеоизображений: [595.0, 27, 16]
# Классические методы машинного обучения: [1087.0, 27, 11]
# Принятие решений: [1561.0, 27, 11]
# Тестирование программного  обеспечения: [1600.0, 27, 11]
# Сетевые средства обеспечения безопасности: [750.0, 27, 12]
# Кросс-платформенные распределенные вычисления: [788.0, 28, 18]
# Современные технологии разработки технической документации: [730.0, 28, 18]
# Проектирование встраиваемых систем на программируемых логических интегральных схемах: [1510.0, 28, 11]
# Конструирование современных электронных средств: [1362.0, 28, 11]
# Технологии поверхностного монтажа: [1205.0, 28, 9]
# Моделирование конструкций и технологических процессов производства электронных средств: [1055.0, 28, 9]
# Учебно-исследовательская работа (прикладная): [1390.0, 28, 11]
# Огневая подготовка из стрелкового оружия: [2424.0, 29, 0]
# Радиационная, химическая и биологическая защита: [2663.0, 29, 0]
# Военная топография: [2420.0, 29, 0]
# Системный анализ и моделирование информационных процессов и систем: [677.0, 29, 19]
# Педагогика и методика преподавания: [849.0, 29, 18]
# Технологии сетей передачи данных: [1668.0, 29, 12]
# Разработка технической документации: [1029.0, 29, 15]
# Компьютерное  моделирование: [1880.0, 29, 8]
# Создание технологического бизнеса: [1947.0, 30, 5]
# Средства разработки цифровых устройств на программируемых логических интегральных схемах: [957.0, 30, 11]
# Системная инженерия: [2453.0, 30, 4]
# Методология научных исследований: [2345.0, 30, 3]
# Локализация технической документации: [2327.0, 30, 5]
# Параллельные вычисления и процессы: [1663.0, 30, 8]
# Обработка больших объемов данных: [1881.0, 30, 6]
# Тестирование программного обеспечения: [2780.0, 30, 2]
# Развитие ресурсов организма: [1563.0, 31, 12]
# Искусственный интеллект для информационной безопасности: [993.0, 32, 2]
# Интеллектуальные агенты и мультиагентные системы: [1449.0, 33, 14]
# Управление разработкой программного обеспечения: [1270.0, 33, 17]
# Интернет-маркетинг и вэб-аналитика: [1660.0, 33, 14]
# Моделирование и оптимизация бизнес-процессов: [1341.0, 33, 17]
# Программирование глубоких нейронных сетей на Python: [1065.0, 34, 20]
# Инструменты бизнес-анализа: [1659.0, 34, 13]
# Архитектура программного обеспечения: [3300.0, 34, 1]
# Инструменты Business Intelligence: [2046.0, 34, 6]
# Компьютерные сети: [2367.0, 35, 5]
# Промышленная разработка ПО и Dev/Ops: [2620.0, 35, 6]
# Компьютерные и сетевые технологии в системах связи: [2313.0, 36, 4]
# Экономика и организация производства: [1144.0, 37, 24]
# Самоменеджмент: [2032.0, 37, 15]
# Спецкурс по системам управления: [605.0, 37, 25]
# Основы полиграфического производства: [2805.0, 38, 1]
# Технические средства управляющих и информационных систем: [1964.0, 40, 15]
# Управление собой: [3480.0, 40, 5]
# Промышленные графические системы: [2624.0, 40, 5]
# Научный семинар по актуальным проблемам науки и производства: [2239.0, 40, 15]
# Учебная практика. ознакомительная: [2421.0, 41, 3]
# Научный семинар по сквозным цифровым технологиям: [2428.0, 41, 13]
# Информационная безопасность: [1225.0, 41, 25]
# Управление продуктами: [1853.0, 41, 14]
# Магистрально-модульные системы реального времени: [2318.0, 41, 16]
# Обеспечение безопасности корпоративной информации: [2084.0, 42, 17]
# Алгоритмы и структуры данных: [2345.0, 43, 10]
# Цифровые устройства: [2250.0, 43, 12]
# Технологии командной разработки программного обеспечения (ПО): [2740.0, 43, 15]
# Теоретические основы электротехники: [1801.0, 44, 4]
# Компоненты электронной техники: [1417.0, 44, 17]
# Материалы электронной техники: [1599.0, 44, 11]
# Защита интеллектуальной собственности: [2167.0, 44, 15]
# Методы принятия управленческих решений: [2030.0, 44, 17]
# Управление рисками ведения бизнеса: [2030.0, 44, 17]
# Алгоритмы управления цветом: [2796.0, 45, 10]
# Технологии цифровой подготовки публикаций: [3436.0, 45, 1]
# Управление командой: [2811.0, 46, 16]
# Разработка вэб-приложений: [2220.0, 46, 19]
# Информационный менеджмент: [3387.0, 46, 9]
# Операционные системы: [3163.0, 47, 5]
# Математические методы для разработчиков 2: [2335.0, 47, 3]
# Разработка мобильных приложений: [2251.0, 47, 16]
# Взаимодействие в команде: [2400.0, 47, 11]
# Администрирование российских операционных систем: [3732.0, 48, 1]
# Русский язык и культура речи: [2778.0, 48, 8]
# Правовые методы и средства информационной безопасности: [2254.0, 49, 19]
# Промышленные сети и защищённая передача данных: [3469.0, 50, 7]
# Технологии интернета вещей: [2819.0, 50, 14]
# Экспертная и аналитическая деятельность в сфере обеспечения безопасности объектов КИИ: [2400.0, 51, 18]
# Реагирование на компьютерные инциденты, ликвидация их последствий на объектах КИИ: [2540.0, 51, 21]
# Стандарты и методы оценки защищенности ИСПДн, ГИС и значимых объектов КИИ: [1875.0, 51, 19]
# Методы и инструменты анализа больших данных: [2235.0, 51, 17]
# Эксплуатация систем обнаружения компьютерных атак на объектах КИИ: [1970.0, 51, 19]
# Методология проектирования защищенных информационных систем: [2225.0, 51, 24]
# Информационные технологии: [2165.0, 51, 12]
# Анализ временных рядов: [1712.0, 52, 27]
# Финансы, денежное обращение и кредит: [3829.0, 53, 1]
# Учебная практика, научно-исследовательская работа: [2190.0, 54, 18]
# Разработка веб-сервисов: [193.0, 54, 52]
# Учебная практика, технологическая: [2972.0, 55, 20]
# Разработка программного обеспечения: [1344.0, 55, 39]
# Производственная практика, технологическая: [2820.0, 57, 18]
# Интеллектуальные и мультиагентные системы: [3655.0, 57, 9]
# Меры и средства защиты информации от несанкционированного доступа в ИСПДн, ГИС и значимых объектах КИИ: [2908.0, 58, 26]
# Безопасность автоматизированных информационно-управляющих систем: [2830.0, 58, 21]
# Методы оптимизации: [1639.0, 58, 30]
# Бухгалтерский учет: [3746.0, 59, 8]
# Деньги, кредит, банки: [3520.0, 59, 7]
# Постреляционные хранилища данных: [1862.0, 59, 32]
# Методы и средства построения программных систем: [2343.0, 59, 27]
# Научный семинар «Публикация  научных результатов»: [2667.0, 59, 29]
# Разработка веб-приложений: [4440.0, 60, 14]
# Современные проблемы информатики и вычислительной техники (научный семинар): [2287.0, 61, 30]
# Математические методы для разработчиков 1: [3442.0, 61, 11]
# Основы личностного роста: [3085.0, 62, 20]
# Общевоинские уставы ВС РФ: [4477.0, 62, 3]
# Строевая подготовка: [4927.0, 62, 3]
# Электротехника: [1809.0, 62, 27]
# Правовые аспекты информационной безопасности ИСПДн, ГИС и значимых объектов КИИ: [2472.0, 62, 24]
# Квалиметрия изображений: [3705.0, 62, 7]
# Математические модели и алгоритмы: [3706.0, 63, 11]
# Специальные разделы математики: [2159.0, 64, 29]
# Криптографические алгоритмы и протоколы: [3106.0, 64, 25]
# Криптографические методы и средства защиты в ИСПДн, ГИС и значимых объектах КИИ: [3086.0, 64, 25]
# Защита информации в системах беспроводной связи: [2694.0, 65, 29]
# Управление разработкой продукта: [5173.0, 65, 8]
# Учебная практика, проектно-технологическая: [1809.0, 66, 45]
# Экономические и гуманитарные аспекты информационных технологий 1: [4613.0, 70, 10]
# Алгоритмы и анализ сложности: [4732.0, 75, 13]
# Математическое моделирование радиотехнических устройств и систем: [3350.0, 79, 33]
# Основы военной подготовки и безопасность жизнедеятельности: [3889.0, 80, 10]
# Управление интеллектуальной собственностью: [4564.0, 80, 25]
# Основы интернета вещей: [3679.0, 81, 12]
# Карьерное развитие молодого специалиста: [6480.0, 81, 6]
# Управление проектами искусственного интеллекта: [2692.0, 82, 45]
# Современные финансовые технологии: [6820.0, 82, 11]
# Радиотехнические системы передачи информации: [1840.0, 84, 49]
# Философские проблемы науки и техники: [4688.0, 85, 26]
# Практическое предпринимательство: [5198.0, 85, 17]
# Физические основы цифровой печати: [5510.0, 85, 12]
# Управление жизненным циклом информационных систем: [4819.0, 87, 23]
# Подготовка научных публикаций: [5300.0, 87, 27]
# Инструменты поддержки принятия решений: [5202.0, 88, 28]
# Аналитика больших данных для бизнеса: [4787.0, 88, 23]
# Учебно-исследовательская общенаучная работа: [5375.0, 88, 28]
# Углубленное программирование на Python: [5805.0, 89, 25]
# Инновации в бизнесе и ИТ: [5265.0, 90, 26]
# Компьютерное зрение: [1921.0, 90, 51]
# Обработка естественного языка: [2322.0, 90, 52]
# Базы данных: [6398.0, 92, 13]
# Дискретная математика и математическая логика: [4646.0, 95, 16]
# Спецкурс 1. Проектирование технических систем: [4322.0, 95, 36]
# Прикладное программирование на языке Python: [4614.0, 95, 35]
# Языки программирования: [5507.0, 99, 16]
# Схемотехника электронных устройств: [6087.0, 99, 15]
# Экономика: [6510.0, 99, 8]
# Компьютерное моделирование физических процессов и систем: [7076.0, 99, 15]
# Электроника и схемотехника: [6274.0, 99, 16]
# Инженерная и компьютерная графика: [5122.0, 100, 8]
# Теория информации: [8322.0, 100, 7]
# Языки и методы программирования: [4637.0, 100, 50]
# Спортивный анализ данных: [4521.0, 103, 39]
# Программирование для встраиваемых систем: [2804.0, 112, 72]
# Проектирование конструкций радиоэлектронных систем: [4023.0, 116, 57]
# Инженерно-техническая реализация систем управления: [7106.0, 121, 36]
# Основы научного исследования: [7072.0, 126, 41]
# Управление проектами в области информационной  безопасности: [6163.0, 127, 46]
# Управление информационной безопасностью ИСПДн, ГИС и значимых объектов КИИ: [6819.0, 127, 47]
# Математические методы теории сигналов и систем: [4836.0, 127, 53]
# Организация защищенных сетевых коммуникаций в ИСПДн, ГИС и на объектах КИИ: [7074.0, 128, 43]
# Актуальные проблемы философии и истории науки: [7242.0, 128, 44]
# Профессиональный иностранный язык: [4980.0, 133, 64]
# Методы контроля защищенности информации ИСПДн, ГИС и значимых объектов КИИ: [4164.0, 138, 66]
# Цифровые двойники в электронике, радиотехнике и системах связи: [2070.0, 140, 109]
# Сбор и верификация данных: [7816.0, 140, 20]
# Современные проблемы радиоэлектроники (научный семинар): [3956.0, 140, 93]
# Проектирование технических систем: [3795.0, 140, 94]
# Разработка ИТ-проекта: [12414.0, 143, 1]
# Учебная практика, ознакомительная: [8703.0, 145, 24]
# Этика искусственного интеллекта: [11471.0, 146, 27]
# Хранение, извлечение и обработка больших данных: [9817.0, 146, 35]
# Разработка приложений: [10600.0, 146, 19]
# Бизнес-применение машинного обучения: [10836.0, 147, 36]
# Разработка систем анализа больших данных: [9232.0, 147, 45]
# Элементарные основы математики: [7275.0, 148, 50]
# Программирование на Java: [11233.0, 156, 25]
# Научный английский (для науки о данных): [10680.0, 161, 29]
# Алгебра, геометрия и теория дифференциальных уравнений: [6594.0, 166, 26]
# Основы теории цепей: [8583.0, 175, 22]
# Автоматизация машинного обучения: [6715.0, 175, 86]
# Методы и средства цифровой обработки сигналов: [7559.0, 176, 84]
# Теория и техника измерений в радиоэлектронике: [6748.0, 176, 69]
# Схемотехника современной радиоэлектроники: [8385.0, 176, 82]
# Физические основы электроники: [3404.0, 185, 133]
# Бизнес коммуникация на английском: [14762.0, 185, 31]
# Вэб-технологии в бизнесе: [9618.0, 188, 66]
# Инжиниринг данных: [10495.0, 191, 61]
# Управление проектами: [10010.0, 194, 66]
# Основы SQL: [11939.0, 207, 63]
# Управление программными проектами: [16394.0, 219, 33]
# Основы информационной безопасности: [14472.0, 241, 24]
# Электроника: [12775.0, 253, 65]
# Глубокие нейронные сети на Python: [16186.0, 269, 81]
# Геометрия: [13165.0, 279, 40]
# Технологии программирования: [15565.0, 283, 51]
# Программирование на PYTHON: [15171.0, 284, 81]
# Алгоритмизация и программирование: [7828.0, 292, 123]
# Автоматизация администрирования MLOps: [19223.0, 311, 95]
# Философия и методология науки: [17522.0, 329, 103]
# Дифференциальные уравнения и численные методы: [10469.0, 363, 127]
# Математические основы анализа данных: [23423.0, 364, 79]
# Операционная система Linux: [27012.0, 374, 78]
# Специальные главы математики: [9893.0, 376, 205]
# Иностранный язык в сфере делового и профессионального общения: [14911.0, 377, 165]
# Алгебра: [21474.0, 391, 60]
# Математические основы искусственного интеллекта: [18798.0, 412, 148]
# Информатика: [27417.0, 418, 30]
# Проектный практикум 3: [27144.0, 421, 91]
# Алгебра и геометрия: [23787.0, 479, 85]
# Компьютерная и инженерная графика: [18690.0, 516, 169]
# Математические основы машинного обучения: [33250.0, 535, 113]
# Программирование на Python: [39544.0, 578, 120]
# Машинное обучение: [33177.0, 666, 220]
# Цифровые компетенции в научной деятельности: [35950.0, 714, 264]
# Архитектура ЭВМ: [43428.0, 720, 176]
# Введение в профессиональную деятельность: [57921.0, 757, 67]
# Программная инженерия: [53140.0, 788, 180]
# Анализ данных и искусственный интеллект: [54289.0, 794, 130]
# Современные языки программирования: [57960.0, 823, 145]
# Теория вероятностей и математическая статистика: [42723.0, 830, 228]
# Проектный практикум 2: [54367.0, 842, 180]
# Web-технологии: [62389.0, 878, 140]
# Введение в специальность: [56685.0, 965, 228]
# Математический анализ: [27250.0, 992, 329]
# Эффективные коммуникации: [86601.0, 1175, 168]
# Дополнительные главы математики: [63260.0, 1286, 211]
# Производственная практика, научно-исследовательская работа: [61281.0, 1316, 532]
# Введение в инженерную деятельность: [83200.0, 1363, 304]
# Элементарные основы физики: [74055.0, 1422, 425]
# Философия: [101723.0, 1629, 335]
# Векторный анализ: [83695.0, 2049, 655]
# Проектный практикум 1: [173985.0, 2598, 349]
# Основы проектной деятельности: [192776.0, 2964, 465]
# Информационные технологии и сервисы: [186517.0, 3012, 611]
# Математика: [159806.0, 3208, 638]
# Основы российской государственности: [216535.0, 3355, 476]
# История России: [201158.0, 3366, 565]
# Программирование: [190529.0, 3394, 598]
# Физика: [253639.0, 4898, 964]
# Иностранный язык: [304796.0, 4948, 853]
# Прикладная физическая культура: [352026.0, 6050, 1217]

# %%
def power_penalty_score(student_scores, subject_stats, p=2.0):
    total_score = 0
    subject_count = 0

    for subject, student_score in student_scores.items():
        stats = subject_stats[subject]
        scores = stats['scores']
        total_students = stats['total_students']

        non_zero_scores = [s for s in scores if s > 0]
        num_fails = total_students - len(non_zero_scores)

        if len(non_zero_scores) == 0 or total_students == 0:
            continue

        mean_clean = sum(non_zero_scores) / len(non_zero_scores)
        fail_ratio = num_fails / total_students

        if student_score < 40:
            if 1 / (fail_ratio + 1e-6) <= 0:
                print(1 / (fail_ratio + 1e-6))
                print(f'fail_ratio: {fail_ratio}')
                print(f'num_fails: {num_fails}')
                print(f'non_zero_scores: {len(non_zero_scores)}')
                print(f'total_students: {total_students}')
                print(f"subject: {subject}")
            multiplier = 1 + math.log(1 / (fail_ratio + 1e-6))
            adjusted = (mean_clean ** p) * multiplier
        else:
            delta = mean_clean - student_score
            signed_power_delta = math.copysign(abs(delta) ** p, delta)
            adjusted = signed_power_delta * fail_ratio

        total_score += adjusted
        subject_count += 1

    if subject_count == 0:
        return None

    return total_score / subject_count

# %%
student_scores = {
    'математика': 100,   # сильно выше среднего
    'история': 50,       # единственный, кто сдал
    'биология': 100      # чуть выше среднего
}

subject_stats = {
    'математика': {'scores': [60, 70, 80, 90, 0, 0, 0], 'total_students': 7},
    'история': {'scores': [0, 0, 0, 50], 'total_students': 4},
    'биология': {'scores': [90, 85, 100, 0, 95], 'total_students': 5}
}

print(power_penalty_score(student_scores, subject_stats))
# Out:
# -93.03571428571428

# %%
def process_scores(df):
    ans = {}
    subject_stats = make_subject_stats(df)

    current_student = None
    student_data = {}

    for index, row in df.iterrows():
        student = row["UUID студента"]
        subject = row["Наименование дисциплины"]
        score = row["Балл"]
        oc = row["Оценка"]

        if student != current_student:
            if current_student is not None:
                ans[current_student] = power_penalty_score(student_data, subject_stats)
            current_student = student
            student_data = {}
        if pd.isna(score):
            score = is_na[oc][0]
        student_data[subject] = score
    
    if current_student is not None:
        ans[current_student] = power_penalty_score(student_data, subject_stats)
    return ans

# %%
def make_subject_stats(df):
    ans = {}
    already_was = {}
    for index, row in df.iterrows():
        subj = row["Наименование дисциплины"]
        student = row["UUID студента"]
        score = row["Балл"]
        oc = row["Оценка"]
        
        if subj not in ans:
            ans[subj] = {'scores': [], 'total_students': 0}
            already_was[subj] = set()
        if pd.isna(score):
            score = is_na[oc][0]
        ans[subj]['scores'].append(score)
        already_was[subj].add(student)
        ans[subj]['total_students'] += 1
    return ans

# %%
df_1_2_dic = make_subject_stats(df_1_2)

# %%
students_scores = process_scores(df_1_2)

# %%
df_1_3 = df_1_2
df_1_3['Наименование дисциплины + семестр'] = (
    df_1_3['Наименование дисциплины'] + '_' + df_1_3['Семестр'].astype(str)
)

# %%
def power_penalty_score(student_scores, subject_stats, p=2.0):
    total_score = 0
    subject_count = 0

    for subject, student_score in student_scores.items():
        stats = subject_stats[subject]
        scores = stats['scores']
        total_students = stats['total_students']

        non_zero_scores = [s for s in scores if s > 0]
        num_fails = total_students - len(non_zero_scores)

        if len(non_zero_scores) == 0 or total_students == 0:
            continue

        mean_clean = sum(non_zero_scores) / len(non_zero_scores)
        fail_ratio = num_fails / total_students

        if student_score < 40:
            if 1 / (fail_ratio + 1e-6) <= 0:
                print(1 / (fail_ratio + 1e-6))
                print(f'fail_ratio: {fail_ratio}')
                print(f'num_fails: {num_fails}')
                print(f'non_zero_scores: {len(non_zero_scores)}')
                print(f'total_students: {total_students}')
                print(f"subject: {subject}")
            multiplier = 1 + math.log(1 / (fail_ratio + 1e-6))
            adjusted = (mean_clean ** p) * multiplier
        else:
            delta = mean_clean - student_score
            signed_power_delta = math.copysign(abs(delta) ** p, delta)
            adjusted = signed_power_delta * fail_ratio

        total_score += adjusted
        subject_count += 1

    if subject_count == 0:
        return None

    return total_score / subject_count

def make_subject_stats(df):
    ans = {}
    for index, row in df.iterrows():
        subj = row["Наименование дисциплины + семестр"]
        student = row["UUID студента"]
        score = row["Балл"]
        oc = row["Оценка"]
        
        if subj not in ans:
            ans[subj] = {'scores': [], 'total_students': 0}
        if pd.isna(score):
            score = is_na[oc][0]
        ans[subj]['scores'].append(score)
        ans[subj]['total_students'] += 1
    return ans

def process_scores(df):
    ans = {}
    subject_stats = make_subject_stats(df)

    current_student = None
    student_data = {}

    for index, row in df.iterrows():
        student = row["UUID студента"]
        subject = row["Наименование дисциплины + семестр"]
        score = row["Балл"]
        oc = row["Оценка"]

        if student != current_student:
            if current_student is not None:
                ans[current_student] = power_penalty_score(student_data, subject_stats)
            current_student = student
            student_data = {}
        if pd.isna(score):
            score = is_na[oc][0]
        student_data[subject] = score
    
    if current_student is not None:
        ans[current_student] = power_penalty_score(student_data, subject_stats)
    return ans

# %%
students_scores = process_scores(df_1_3)

# %%
sorted_items = sorted(students_scores.items(), key=lambda x: x[1])

# Вывод ключей и значений
i = 1
for key, value in sorted_items:
    print(f"{i} {key}: {value}")
    i += 1
# Out:
# 1 studen195e3pg0000okb2i4mgg0mn2qg: -251.232553128848
# 2 studen195e3pg0000okb2j3gma5qo06k: -198.55900754390643
# 3 studen195e3pg0000okb2nl8amqt4jpo: -182.290200366767
# 4 studen195e3pg0000okb2se434o1nma4: -181.42351748831726
# 5 studen195e3pg0000ok231171mgmkotk: -177.78972730460666
# 6 studen195e3pg0000p2rsb4j9bteoims: -174.44770769641454
# 7 studen195e3pg0000p2rtkp7dph287o0: -158.0060783975035
# 8 studen195e3pg0000p2sf6d79p6pmjdc: -157.4699325831978
# 9 studen195e3pg0000oksqbecn97q50a8: -156.93852715670522
# 10 studen195e3pg0000okb2rr7qovdb46c: -151.2656041910931
# 11 studen195e3pg0000p2udd4muf31vi2c: -149.48393242365265
# 12 studen195e3pg0000ok22tp3e8r0b7oo: -142.0089066254978
# 13 studen195e3pg0000okb2dtmlbl1cs50: -137.66664400784347
# 14 studen195e3pg0000p2udcrur9t791lo: -136.5601215815301
# 15 studen195e3pg0000ok2137iuojoetp4: -135.6426177250576
# 16 studen195e3pg0000ok22ugtqmhvh9u4: -132.73800502422955
# 17 studen195e3pg0000ok21ad8n7amre6c: -132.50720316022625
# 18 studen195e3pg0000ok211k6ph78258o: -128.4789036444259
# 19 studen195e3pg0000p364o2qt1ijiur4: -126.1040952728737
# 20 studen195e3pg0000p2rsguaod8fs4e8: -124.97777937174513
# 21 studen195e3pg0000p2udklod6ukaj4g: -124.78383273919998
# 22 studen195e3pg0000ok231vjgg4i2rb4: -124.13082673937454
# 23 studen195e3pg0000ok2312fjnl102p8: -123.42703254885406
# 24 studen195e3pg0000ok236o67oa8dvs8: -123.00925401070945
# 25 studen195e3pg0000okb2ob2l1tkef44: -122.36493429744283
# 26 studen195e3pg0000p2rt1i4lqc19150: -120.6224564888521
# 27 studen195e3pg0000p2udg5u9ekjh8ag: -120.17111034301303
# 4490 studen195e3pg0000p2uairo5krkcvj4: 16993.664821267685
# 4491 studen195e3pg0000p2u9llust7ou9vs: 17014.19868246248
# 4492 studen195e3pg0000oksqbtc1vnjk5i0: 17403.376885614944
# 4493 studen195e3pg0000okiqin593mkuv0c: 17589.76908317223
# 4494 studen195e3pg0000olpct4pi2r028h8: 17897.917824539618
# 4495 studen195e3pg0000ol61fandjk5a53s: 17897.91782453962
# 4496 studen195e3pg0000ol61eogc3ad8o6c: 17897.91782453962
# 4497 studen195e3pg0000oksqd31sdbgedj0: 17897.91782453962
# 4498 studen195e3pg0000olevpob0v5cm330: 17897.91782453962
# 4499 studen195e3pg0000ol61g7ho33vmbb4: 17897.917824539625
# 4500 studen195e3pg0000olevpm4b0j0b46s: 17897.917824539625
# 4501 studen195e3pg0000okb30c0cj1sicf8: 17897.917824539625
# 4502 studen195e3pg0000om8nbib216dke9g: 17897.917824539625
# 4503 studen195e3pg0000okb2ghc723ud5dg: 18031.301281967302
# 4504 studen195e3pg0000p3dsjhkanobul4c: 18031.301281967302
# 4505 studen195e3pg0000ol61h96sqo26d8s: 18178.721639953532
# 4506 studen195e3pg0000om8nb57e032vje4: 18199.334064502214
# 4507 studen195e3pg0000olpcsh02a10lr40: 18336.20830444473
# 4508 studen195e3pg0000om8nc93inl7l9h0: 18336.20830444473
# 4509 studen195e3pg0000olmtisghr5fv0g0: 18484.47589799427
# 4510 studen195e3pg0000ol61f72700c37us: 18484.47589799427
# 4511 studen195e3pg0000om8nc0cgto4q8gg: 18484.47589799427
# 4512 studen195e3pg0000oksqaup9seq8tj0: 18484.47589799427
# 4513 studen195e3pg0000om8nbdmcsmiqkms: 18484.47589799427
# 4514 studen195e3pg0000om8nagh2hm7g770: 18484.47589799427
# 4515 studen195e3pg0000olevpifc9v8sdok: 18484.47589799427
# 4516 studen195e3pg0000okb309jta3ji3sc: 18484.47589799427
# 4517 studen195e3pg0000olevpq5i3098dho: 18484.47589799427
# 4518 studen195e3pg0000olevpg5hahbulp0: 18484.475897994274
# 4519 studen195e3pg0000okiqhmjlgcnhuuc: 18484.475897994274
# 4520 studen195e3pg0000oksqc3kvito7ctc: 18484.475897994274
# 4521 studen195e3pg0000oksqb35qgvfqhpo: 18484.475897994274
# 4522 studen195e3pg0000om8nbsnku66g3tk: 18484.475897994274
# 4523 studen195e3pg0000ol61e59t7g8fcp8: 19174.06772374142
# 4524 studen195e3pg0000olmtgs2enedcpqs: 19174.06772374142
# 4525 studen195e3pg0000p2u9ufa9d8g2ke0: 21474.66741361166
# 4526 studen195e3pg0000p2uahni4t0gmr2c: 21474.667413611664
# 4527 studen195e3pg0000okiqih08go9l7n0: 22486.835915861306
# 4528 studen195e3pg0000p2ua7j2jgdldrng: 23467.9381965701

# %%
print(students_scores['studen195e3pg0000ok20qioftk2s0g8'])
# Out:
# -51.758128340029366

# %%
df_1_2.to_csv('../../data/datasets/dataset_1_2.csv', sep=';', index=False, encoding='utf-8-sig')
df_1_3.to_csv('../../data/datasets/dataset_1_3.csv', sep=';', index=False, encoding='utf-8-sig')
