# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('../../data/datasets/dataset_1_3.csv', sep=';', encoding='utf-8-sig', low_memory=False)

# %%
df.head()
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 1  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 2  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 3  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 4  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                      NaN  Особая квота                    NaN           NaN
# 1                      NaN  Особая квота                    NaN           NaN
# 2                      NaN  Особая квота                    NaN           NaN
# 3                      NaN  Особая квота                    NaN           NaN
# 4                      NaN  Особая квота                    NaN           NaN
#
#   Категория конкурса БВИ                       UUID оценки  ...  \
# 0                    NaN  qldflt195e3pg0000p0ojcks1r0brulk  ...
# 1                    NaN  qldflt195e3pg0000p9a199s0tmd01fs  ...
# 2                    NaN  qldflt195e3pg0000p9a1uimadbqc25o  ...
# 3                    NaN  qldflt195e3pg0000p91r12floo1c7uc  ...
# 4                    NaN  qldflt195e3pg0000oqc4snbpauvougo  ...
#
#   Город законченного уч. зав. Тип законченного уч. зав.  \
# 0                  не указано                   Колледж
# 1                  не указано                   Колледж
# 2                  не указано                   Колледж
# 3                  не указано                   Колледж
# 4                  не указано                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 1  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 2  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 3  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 4  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании  Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                       NaN
# 1  Диплом о среднем профессиональном образовании                       NaN
# 2  Диплом о среднем профессиональном образовании                       NaN
# 3  Диплом о среднем профессиональном образовании                       NaN
# 4  Диплом о среднем профессиональном образовании                       NaN
#
#   Специальность зак.уч.зав.                                    Льготы  \
# 0                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 1                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 2                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 3                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 4                       NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  \
# 0  31 Копия свидетельства о смерти матери
# 1  31 Копия свидетельства о смерти матери
# 2  31 Копия свидетельства о смерти матери
# 3  31 Копия свидетельства о смерти матери
# 4  31 Копия свидетельства о смерти матери
#
#            Наименование дисциплины + семестр
# 0                    Проектный практикум 1_2
# 1                          Архитектура ЭВМ_3
# 2  Анализ данных и искусственный интеллект_3
# 3           Прикладная физическая культура_3
# 4           Прикладная физическая культура_1
#
# [5 rows x 67 columns]

# %%
df_1_sem = df[df["Сквозной семестр"] < 3]
df_1_sem = df_1_sem[df_1_sem["Год начала обучения"] == 2023]

# %%
df_1_sem.head()
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 4  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 6  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 7  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 8  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                      NaN  Особая квота                    NaN           NaN
# 4                      NaN  Особая квота                    NaN           NaN
# 6                      NaN  Особая квота                    NaN           NaN
# 7                      NaN  Особая квота                    NaN           NaN
# 8                      NaN  Особая квота                    NaN           NaN
#
#   Категория конкурса БВИ                       UUID оценки  ...  \
# 0                    NaN  qldflt195e3pg0000p0ojcks1r0brulk  ...
# 4                    NaN  qldflt195e3pg0000oqc4snbpauvougo  ...
# 6                    NaN  qldflt195e3pg0000oqib6f365d55omc  ...
# 7                    NaN  qldflt195e3pg0000p0okbqkb7dg8u54  ...
# 8                    NaN  qldflt195e3pg0000os603jlf5koit64  ...
#
#   Город законченного уч. зав. Тип законченного уч. зав.  \
# 0                  не указано                   Колледж
# 4                  не указано                   Колледж
# 6                  не указано                   Колледж
# 7                  не указано                   Колледж
# 8                  не указано                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 4  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 6  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 7  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 8  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании  Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                       NaN
# 4  Диплом о среднем профессиональном образовании                       NaN
# 6  Диплом о среднем профессиональном образовании                       NaN
# 7  Диплом о среднем профессиональном образовании                       NaN
# 8  Диплом о среднем профессиональном образовании                       NaN
#
#   Специальность зак.уч.зав.                                    Льготы  \
# 0                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 4                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 6                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 7                       NaN  02 Лица из числа детей-сирот (до 23 лет)
# 8                       NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  Наименование дисциплины + семестр
# 0  31 Копия свидетельства о смерти матери            Проектный практикум 1_2
# 4  31 Копия свидетельства о смерти матери   Прикладная физическая культура_1
# 6  31 Копия свидетельства о смерти матери                       Математика_1
# 7  31 Копия свидетельства о смерти матери                        Философия_2
# 8  31 Копия свидетельства о смерти матери                       Математика_1
#
# [5 rows x 67 columns]

# %%
df_1_sem['Балл за инд. достижения'] = df_1_sem['Балл за инд. достижения'].fillna(0)

# %%
df_1_sem.isna().sum()
# Out:
# UUID студента                            0
# Приоритет                                0
# Cумма баллов испытаний                   0
# БВИ                                      0
# Балл за инд. достижения                  0
#                                      ...
# Квалификация зак.уч.зав.             36866
# Специальность зак.уч.зав.            34742
# Льготы                               44808
# Документы подтв. льготы              44998
# Наименование дисциплины + семестр        0
# Length: 67, dtype: int64

# %%
df_1_sem["Новый таргет"] = df_1_sem["Состояние студента"]

# %%
df_1_sem.head()
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 4  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 6  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 7  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 8  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                      0.0  Особая квота                    NaN           NaN
# 4                      0.0  Особая квота                    NaN           NaN
# 6                      0.0  Особая квота                    NaN           NaN
# 7                      0.0  Особая квота                    NaN           NaN
# 8                      0.0  Особая квота                    NaN           NaN
#
#   Категория конкурса БВИ                       UUID оценки  ...  \
# 0                    NaN  qldflt195e3pg0000p0ojcks1r0brulk  ...
# 4                    NaN  qldflt195e3pg0000oqc4snbpauvougo  ...
# 6                    NaN  qldflt195e3pg0000oqib6f365d55omc  ...
# 7                    NaN  qldflt195e3pg0000p0okbqkb7dg8u54  ...
# 8                    NaN  qldflt195e3pg0000os603jlf5koit64  ...
#
#   Тип законченного уч. зав.  \
# 0                   Колледж
# 4                   Колледж
# 6                   Колледж
# 7                   Колледж
# 8                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 4  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 6  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 7  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 8  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
# 4  Диплом о среднем профессиональном образовании                      NaN
# 6  Диплом о среднем профессиональном образовании                      NaN
# 7  Диплом о среднем профессиональном образовании                      NaN
# 8  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 4                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 6                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 7                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 8                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  Наименование дисциплины + семестр  \
# 0  31 Копия свидетельства о смерти матери            Проектный практикум 1_2
# 4  31 Копия свидетельства о смерти матери   Прикладная физическая культура_1
# 6  31 Копия свидетельства о смерти матери                       Математика_1
# 7  31 Копия свидетельства о смерти матери                        Философия_2
# 8  31 Копия свидетельства о смерти матери                       Математика_1
#
#    Новый таргет
# 0      Активный
# 4      Активный
# 6      Активный
# 7      Активный
# 8      Активный
#
# [5 rows x 68 columns]

# %%
# Сначала создаём маску с правильными условиями
mask = (
    ((df_1_sem["Курс"] != 1) & 
    (df_1_sem["Состояние студента"] != "Активный")) |
    ((df_1_sem["Сквозной семестр"] != 1) & 
    (df_1_sem["Состояние студента"] != "Активный"))
)

# Затем обновляем значения для строк, соответствующих маске
df_1_sem.loc[mask, "Новый таргет"] = "Активный"

# %%
df_1_sem["Новый таргет"].head()
# Out:
# 0    Активный
# 4    Активный
# 6    Активный
# 7    Активный
# 8    Активный
# Name: Новый таргет, dtype: object

# %%
# Выбираем строки, где "Состояние студента" != "новый таргет"
changed_rows = df_1_sem[df_1_sem["Состояние студента"] != df_1_sem["Новый таргет"]]

# Выводим результат (можно добавить фильтр по нужным столбцам)
changed_rows[["UUID студента", "Состояние студента", "Новый таргет", "Курс", "Сквозной семестр"]]
# Out:
#                           UUID студента Состояние студента Новый таргет  Курс  \
# 368    studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 373    studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 374    studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 376    studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 377    studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# ...                                 ...                ...          ...   ...
# 61271  studen195e3pg0000ok208bl08bh35t4           Отчислен     Активный     1
# 61272  studen195e3pg0000ok208bl08bh35t4           Отчислен     Активный     1
# 61274  studen195e3pg0000ok208bl08bh35t4           Отчислен     Активный     1
# 61276  studen195e3pg0000ok208bl08bh35t4           Отчислен     Активный     1
# 61277  studen195e3pg0000ok208bl08bh35t4           Отчислен     Активный     1
#
#        Сквозной семестр
# 368                   2
# 373                   2
# 374                   2
# 376                   2
# 377                   2
# ...                 ...
# 61271                 2
# 61272                 2
# 61274                 2
# 61276                 2
# 61277                 2
#
# [5007 rows x 5 columns]

# %%
changed_rows[["UUID студента", "Состояние студента", "Новый таргет", "Курс", "Сквозной семестр"]].head(30)
# Out:
#                         UUID студента Состояние студента Новый таргет  Курс  \
# 368  studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 373  studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 374  studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 376  studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 377  studen195e3pg0000ok202gfub3pbmj4           Отчислен     Активный     1
# 540  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 541  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 544  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 545  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 546  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 550  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 553  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 554  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 555  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 560  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 561  studen195e3pg0000ok21ho0mk63onnk           Отчислен     Активный     1
# 714  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 715  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 717  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 722  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 723  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 724  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 727  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 728  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 731  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 732  studen195e3pg0000ok20h7lid3nit9k           Отчислен     Активный     1
# 734  studen195e3pg0000ok2328o67lpdh38           Отчислен     Активный     2
# 735  studen195e3pg0000ok2328o67lpdh38           Отчислен     Активный     2
# 736  studen195e3pg0000ok2328o67lpdh38           Отчислен     Активный     2
# 737  studen195e3pg0000ok2328o67lpdh38           Отчислен     Активный     2
#
#      Сквозной семестр
# 368                 2
# 373                 2
# 374                 2
# 376                 2
# 377                 2
# 540                 2
# 541                 2
# 544                 2
# 545                 2
# 546                 2
# 550                 2
# 553                 2
# 554                 2
# 555                 2
# 560                 2
# 561                 2
# 714                 2
# 715                 2
# 717                 2
# 722                 2
# 723                 2
# 724                 2
# 727                 2
# 728                 2
# 731                 2
# 732                 2
# 734                 2
# 735                 1
# 736                 2
# 737                 2

# %%
df_1_sem = df_1_sem.drop("Состояние студента", axis=1)

# %%
df_1_sem.head(1)
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                      0.0  Особая квота                    NaN           NaN
#
#   Категория конкурса БВИ                       UUID оценки  ...  \
# 0                    NaN  qldflt195e3pg0000p0ojcks1r0brulk  ...
#
#   Тип законченного уч. зав.  \
# 0                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  Наименование дисциплины + семестр  \
# 0  31 Копия свидетельства о смерти матери            Проектный практикум 1_2
#
#    Новый таргет
# 0      Активный
#
# [1 rows x 67 columns]

# %%
df_1_sem["Балл за инд. достижения"].unique()
# Out:
# array([ 0.,  3.,  2.,  5.,  6., 10.,  7.,  9.,  4.,  8.,  1.])

# %%
df_1_sem["Балл за инд. достижения"] = df_1_sem["Балл за инд. достижения"].astype(int)

# %%
df_1_sem.head(1)
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                        0  Особая квота                    NaN           NaN
#
#   Категория конкурса БВИ                       UUID оценки  ...  \
# 0                    NaN  qldflt195e3pg0000p0ojcks1r0brulk  ...
#
#   Тип законченного уч. зав.  \
# 0                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  Наименование дисциплины + семестр  \
# 0  31 Копия свидетельства о смерти матери            Проектный практикум 1_2
#
#    Новый таргет
# 0      Активный
#
# [1 rows x 67 columns]

# %%
df_1_sem["Вид конкурса"].unique()
# Out:
# array(['Особая квота', 'Целевая квота', 'Отдельная квота',
#        'Основные места'], dtype=object)

# %%
benefit = df_1_sem["Льготы"].unique()

# %%
benefit
# Out:
# array(['02 Лица из числа детей-сирот (до 23 лет)', nan,
#        '04 Дети-инвалиды',
#        '05 Лица из числа детей без попечения родителей (до 23 лет)',
#        '21 Дети военнослужащих, погибших или получивших увечье при исполнении обязанностей военной службы в специальной военной операции на территориях Украины',
#        '07 Инвалиды с детства',
#        '19 Дети лиц, принимавших участие в специальной военной операции на территориях Украины',
#        '17 Дети военнослужащих, сотрудников федеральных органов исполнительной власти и федеральных государственных органов, направленных в другие государства',
#        '11 Инвалиды II группы', '10 Ветераны боевых действий',
#        '03 Дети, оставшиеся без попечения родителей (до 18 лет)',
#        '09 Лица, поступающие по направлению Министерства в пределах квоты, установленной Правительством Российской Федерации'],
#       dtype=object)

# %%
df_1_sem["Категория конкурса БВИ"].unique()
# Out:
# array([nan,
#        '21 Дети военнослужащих, погибших или получивших увечье при исполнении обязанностей военной службы в специальной военной операции на территориях Украины',
#        '2020:  Всероссийская олимпиада школьников',
#        '62 Открытая олимпиада школьников',
#        '26 Международная олимпиада школьников Уральского федерального университета "Изумруд"',
#        '09 Лица, поступающие по направлению Министерства в пределах квоты, установленной Правительством Российской Федерации',
#        '2022: 25 Международная олимпиада школьников Уральского федерального университета "Изумруд"',
#        '64 Открытая олимпиада школьников по программированию "Когнитивные технологии"',
#        '2022: 37 Многопрофильная инженерная олимпиада "Звезда"',
#        '36 Многопрофильная инженерная олимпиада "Звезда"',
#        '67 Отраслевая олимпиада школьников "Газпром"',
#        '79 Университетская олимпиада школьников "Бельчонок"',
#        '2022: 15 Вузовско-академическая олимпиада по информатике',
#        '47 Олимпиада школьников "Гранит науки"',
#        '2020: 35 Многопрофильная олимпиада школьников Уральского федерального университета «Изумруд»',
#        '15 Вузовско-академическая олимпиада по информатике',
#        'Лица, поступающие по направлению Министерства в пределах квоты, установленной Правительством Российской Федерации'],
#       dtype=object)

# %%
df_1_sem.loc[df_1_sem["Категория конкурса БВИ"].isin(benefit), "Категория конкурса БВИ"] = np.nan

# %%
# Выводим строки, где "Категория конкурса БВИ" стала NaN
df_1_sem[df_1_sem["Категория конкурса БВИ"].isna()].head()

# Или проверяем количество изменений:
# print("Число замененных строк:", df_1_sem["Категория конкурса БВИ"].isna().sum())
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 4  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 6  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 7  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 8  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                        0  Особая квота                    NaN           NaN
# 4                        0  Особая квота                    NaN           NaN
# 6                        0  Особая квота                    NaN           NaN
# 7                        0  Особая квота                    NaN           NaN
# 8                        0  Особая квота                    NaN           NaN
#
#   Категория конкурса БВИ                       UUID оценки  ...  \
# 0                    NaN  qldflt195e3pg0000p0ojcks1r0brulk  ...
# 4                    NaN  qldflt195e3pg0000oqc4snbpauvougo  ...
# 6                    NaN  qldflt195e3pg0000oqib6f365d55omc  ...
# 7                    NaN  qldflt195e3pg0000p0okbqkb7dg8u54  ...
# 8                    NaN  qldflt195e3pg0000os603jlf5koit64  ...
#
#   Тип законченного уч. зав.  \
# 0                   Колледж
# 4                   Колледж
# 6                   Колледж
# 7                   Колледж
# 8                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 4  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 6  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 7  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
# 8  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
# 4  Диплом о среднем профессиональном образовании                      NaN
# 6  Диплом о среднем профессиональном образовании                      NaN
# 7  Диплом о среднем профессиональном образовании                      NaN
# 8  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 4                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 6                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 7                        NaN  02 Лица из числа детей-сирот (до 23 лет)
# 8                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  Наименование дисциплины + семестр  \
# 0  31 Копия свидетельства о смерти матери            Проектный практикум 1_2
# 4  31 Копия свидетельства о смерти матери   Прикладная физическая культура_1
# 6  31 Копия свидетельства о смерти матери                       Математика_1
# 7  31 Копия свидетельства о смерти матери                        Философия_2
# 8  31 Копия свидетельства о смерти матери                       Математика_1
#
#    Новый таргет
# 0      Активный
# 4      Активный
# 6      Активный
# 7      Активный
# 8      Активный
#
# [5 rows x 67 columns]

# %%
df_1_sem[df_1_sem["UUID студента"] == "studen195e3pg0000ok210qds16h2lps"].head(1)
# Out:
#                         UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 281  studen195e3pg0000ok210qds16h2lps          1                       0    1
#
#      Балл за инд. достижения     Вид конкурса Наименование олимпиады  \
# 281                        0  Отдельная квота                    NaN
#
#     Тип олимпиады Категория конкурса БВИ                       UUID оценки  \
# 281           NaN                    NaN  qldflt195e3pg0000p4j535qjr0kade4
#
#      ...          Тип законченного уч. зав.  \
# 281  ...  Средняя общеобразовательная школа
#
#                         Название законченного уч. зав. Год окончание уч. зав.  \
# 281  Средняя общеобразовательная школа Муниципально...                   2023
#
#              Тип документа об образовании Квалификация зак.уч.зав.  \
# 281  Аттестат о среднем общем образовании                      NaN
#
#      Специальность зак.уч.зав.  \
# 281                        NaN
#
#                                                 Льготы  \
# 281  21 Дети военнослужащих, погибших или получивши...
#
#                                Документы подтв. льготы  \
# 281  Документ, подтверждающий принадлежность к детя...
#
#                    Наименование дисциплины + семестр  Новый таргет
# 281  Дифференциальные уравнения и численные методы_2      Активный
#
# [1 rows x 67 columns]

# %%
df_1_sem["Категория конкурса БВИ"].unique()
# Out:
# array([nan, '2020:  Всероссийская олимпиада школьников',
#        '62 Открытая олимпиада школьников',
#        '26 Международная олимпиада школьников Уральского федерального университета "Изумруд"',
#        '2022: 25 Международная олимпиада школьников Уральского федерального университета "Изумруд"',
#        '64 Открытая олимпиада школьников по программированию "Когнитивные технологии"',
#        '2022: 37 Многопрофильная инженерная олимпиада "Звезда"',
#        '36 Многопрофильная инженерная олимпиада "Звезда"',
#        '67 Отраслевая олимпиада школьников "Газпром"',
#        '79 Университетская олимпиада школьников "Бельчонок"',
#        '2022: 15 Вузовско-академическая олимпиада по информатике',
#        '47 Олимпиада школьников "Гранит науки"',
#        '2020: 35 Многопрофильная олимпиада школьников Уральского федерального университета «Изумруд»',
#        '15 Вузовско-академическая олимпиада по информатике',
#        'Лица, поступающие по направлению Министерства в пределах квоты, установленной Правительством Российской Федерации'],
#       dtype=object)

# %%
benefit
# Out:
# array(['02 Лица из числа детей-сирот (до 23 лет)', nan,
#        '04 Дети-инвалиды',
#        '05 Лица из числа детей без попечения родителей (до 23 лет)',
#        '21 Дети военнослужащих, погибших или получивших увечье при исполнении обязанностей военной службы в специальной военной операции на территориях Украины',
#        '07 Инвалиды с детства',
#        '19 Дети лиц, принимавших участие в специальной военной операции на территориях Украины',
#        '17 Дети военнослужащих, сотрудников федеральных органов исполнительной власти и федеральных государственных органов, направленных в другие государства',
#        '11 Инвалиды II группы', '10 Ветераны боевых действий',
#        '03 Дети, оставшиеся без попечения родителей (до 18 лет)',
#        '09 Лица, поступающие по направлению Министерства в пределах квоты, установленной Правительством Российской Федерации'],
#       dtype=object)

# %%
df_1_sem['Категория конкурса БВИ'] = np.where(df_1_sem['Категория конкурса БВИ'].notna(), '1', "0")

# %%
df_1_sem['Категория конкурса БВИ'].unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
df_1_sem['Категория конкурса БВИ']
# Out:
# 0        0
# 4        0
# 6        0
# 7        0
# 8        0
#         ..
# 68486    1
# 68487    1
# 68488    1
# 68489    1
# 68493    1
# Name: Категория конкурса БВИ, Length: 46421, dtype: object

# %%
df_1_sem['Категория конкурса БВИ'] = df_1_sem['Категория конкурса БВИ'].astype(int)

# %%
# df_1_sem["Льготы"] = np.where(df_1_sem["Льготы"].notna(), '1', "0")

# %%
# df_1_sem["Льготы"] = df_1_sem['Льготы'].astype(int)

# %%
df_1_sem.head(1)
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Наименование олимпиады Тип олимпиады  \
# 0                        0  Особая квота                    NaN           NaN
#
#    Категория конкурса БВИ                       UUID оценки  ...  \
# 0                       0  qldflt195e3pg0000p0ojcks1r0brulk  ...
#
#   Тип законченного уч. зав.  \
# 0                   Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы  Наименование дисциплины + семестр  \
# 0  31 Копия свидетельства о смерти матери            Проектный практикум 1_2
#
#    Новый таргет
# 0      Активный
#
# [1 rows x 67 columns]

# %%
df_1_sem = df_1_sem.drop("Наименование олимпиады", axis=1)

# %%
df_1_sem = df_1_sem.drop("UUID оценки", axis=1)

# %%
columns_lst = df_1_sem.columns

# %%
print(*columns_lst.to_list(), sep='\n')
# Out:
# UUID студента
# Приоритет
# Cумма баллов испытаний
# БВИ
# Балл за инд. достижения
# Вид конкурса
# Тип олимпиады
# Категория конкурса БВИ
# Контрольное мероприятие
# Тип оценки
# Наименование дисциплины
# Модель реализации
# Оценка
# Балл
# Дата получения оценки
# Семестр
# Сквозной семестр
# Год
# Наименование дисциплины ИТС
# ИТС наименование в дипломе
# Код направления подготовки
# Наименование напр. подготовки
# Образовательная программа
# ЛН студента
# ЛН студента (архив)
# Основа освоения (сокр.)
# Форма освоения
# Формирующее подразделение
# Год начала обучения
# Срок освоения
# Уровень подготовки
# Область образования
# Целевик
# Хоз. группа | Вкл. обучение
# Нуждается в общежитии
# Малоимущий
# Слушатель
# Иностранный абитуриент (МОН)
# Курс
# Активное состояние
# В архиве
# Приказ об отчислении
# Акад. отп. по сост. здор.
# Акад. отп. по уходу за реб.
# UUID персоны
# Пол
# Дата рождения
# Место рождения
# Гражданство
# Адрес регистрации. Страна
# Адрес регистрации. Область
# Адрес регистрации. Город
# Страна законченного уч. зав.
# Регион законченного уч. зав.
# Город законченного уч. зав.
# Тип законченного уч. зав.
# Название законченного уч. зав.
# Год окончание уч. зав.
# Тип документа об образовании
# Квалификация зак.уч.зав.
# Специальность зак.уч.зав.
# Льготы
# Документы подтв. льготы
# Наименование дисциплины + семестр
# Новый таргет

# %%
columns_to_drop = ["Контрольное мероприятие", "Тип оценки", "Наименование дисциплины", "Модель реализации", "Оценка", "Балл",
                   "Дата получения оценки", "Семестр", "Сквозной семестр", "Год", "Наименование дисциплины ИТС", "ИТС наименование в дипломе",
                   "Год начала обучения", "Курс", "Активное состояние", "Место рождения", "Наименование дисциплины + семестр"]

df_1_sem_1 = df_1_sem.drop(columns=columns_to_drop)

# %%
df_1_sem_1.head(1)
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Тип олимпиады  \
# 0                        0  Особая квота           NaN
#
#    Категория конкурса БВИ Код направления подготовки  \
# 0                       0                   09.03.04
#
#   Наименование напр. подготовки  ... Город законченного уч. зав.  \
# 0         Программная инженерия  ...                  не указано
#
#    Тип законченного уч. зав.  \
# 0                    Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы Новый таргет
# 0  31 Копия свидетельства о смерти матери     Активный
#
# [1 rows x 48 columns]

# %%
# df_1_sem = df_1_sem.drop("UUID оценки", axis=1)
df_1_sem_1["Код направления подготовки"].nunique()
# Out:
# 20

# %%
df_1_sem_1["Образовательная программа"].nunique()
# Out:
# 27

# %%
lst1 = df_1_sem_1["Наименование напр. подготовки"].unique().tolist()
lst2 = df_1_sem_1["Образовательная программа"].unique().tolist()

# for val in lst1:
#     lst2.remove(val)
lst1.sort()
lst2.sort()

print(lst1)
print(lst2)
# Out:
# ['Инфокоммуникационные технологии и системы связи', 'Информатика и вычислительная техника', 'Информационная безопасность', 'Информационная безопасность телекоммуникационных систем', 'Информационно-аналитические системы безопасности', 'Информационные системы и технологии', 'Конструирование и технология электронных средств', 'Прикладная информатика', 'Программная инженерия', 'Радиотехника', 'Радиоэлектронные системы и комплексы', 'Технология полиграфического и упаковочного производства', 'Управление в технических системах']
# ['IT инновации в бизнесе', 'Алгоритмы искусственного интеллекта', 'Безопасность компьютерных систем', 'Защита информации в информационных системах персональных данных, государственных информационных системах и значимых объектах критической информационной инфраструктуры', 'Инженерия искусственного интеллекта', 'Инженерия машинного обучения', 'Инженерия радиоэлектронных средств и систем', 'Интеллектуальные информационные системы и технологии в медицине', 'Инфокоммуникационные технологии и системы связи', 'Информатика и вычислительная техника', 'Информационная безопасность телекоммуникационных систем', 'Информационно-аналитические системы безопасности', 'Информационно-управляющие системы', 'Конструирование и технология электронных средств', 'Прикладная информатика', 'Прикладной анализ данных', 'Прикладной искусственный интеллект', 'Программная инженерия', 'Промышленные графические системы и цифровые фототехнологии', 'Радиотехника', 'Радиоэлектронные системы и комплексы', 'Разработка и управление в программных проектах', 'Разработка программно-информационных систем', 'Системы управления сложными объектами и процессами', 'Технология полиграфического и упаковочного производства', 'Управление в технических системах', 'Электроника, радиотехника и системы связи']

# %%
sorted_list = sorted(df_1_sem_1["Код направления подготовки"].unique().tolist())
sorted_list
# Out:
# ['09.03.01',
#  '09.03.03',
#  '09.03.04',
#  '09.04.01',
#  '09.04.02',
#  '09.04.03',
#  '09.04.04',
#  '10.03.01',
#  '10.04.01',
#  '10.05.02',
#  '10.05.04',
#  '11.03.01',
#  '11.03.02',
#  '11.03.03',
#  '11.04.01',
#  '11.05.01',
#  '27.03.04',
#  '27.04.04',
#  '29.03.03',
#  '29.04.03']

# %%
df_1_sem_1.columns
# Out:
# Index(['UUID студента', 'Приоритет', 'Cумма баллов испытаний', 'БВИ',
#        'Балл за инд. достижения', 'Вид конкурса', 'Тип олимпиады',
#        'Категория конкурса БВИ', 'Код направления подготовки',
#        'Наименование напр. подготовки', 'Образовательная программа',
#        'ЛН студента', 'ЛН студента (архив)', 'Основа освоения (сокр.)',
#        'Форма освоения', 'Формирующее подразделение', 'Срок освоения',
#        'Уровень подготовки', 'Область образования', 'Целевик',
#        'Хоз. группа | Вкл. обучение', 'Нуждается в общежитии', 'Малоимущий',
#        'Слушатель', 'Иностранный абитуриент (МОН)', 'В архиве',
#        'Приказ об отчислении', 'Акад. отп. по сост. здор.',
#        'Акад. отп. по уходу за реб.', 'UUID персоны', 'Пол', 'Дата рождения',
#        'Гражданство', 'Адрес регистрации. Страна',
#        'Адрес регистрации. Область', 'Адрес регистрации. Город',
#        'Страна законченного уч. зав.', 'Регион законченного уч. зав.',
#        'Город законченного уч. зав.', 'Тип законченного уч. зав.',
#        'Название законченного уч. зав.', 'Год окончание уч. зав.',
#        'Тип документа об образовании', 'Квалификация зак.уч.зав.',
#        'Специальность зак.уч.зав.', 'Льготы', 'Документы подтв. льготы',
#        'Новый таргет'],
#       dtype='object')

# %%
lst1 = df_1_sem_1["Наименование напр. подготовки"].to_list()
lst2 = df_1_sem_1["Наименование напр. подготовки"].to_list()

# %%
df_1_sem_1.head(1)
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Тип олимпиады  \
# 0                        0  Особая квота           NaN
#
#    Категория конкурса БВИ Код направления подготовки  \
# 0                       0                   09.03.04
#
#   Наименование напр. подготовки  ... Город законченного уч. зав.  \
# 0         Программная инженерия  ...                  не указано
#
#    Тип законченного уч. зав.  \
# 0                    Колледж
#
#                       Название законченного уч. зав. Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                   2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
#
#    Специальность зак.уч.зав.                                    Льготы  \
# 0                        NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы Новый таргет
# 0  31 Копия свидетельства о смерти матери     Активный
#
# [1 rows x 48 columns]

# %%
df_1_sem_2 = df_1_sem_1.drop_duplicates(subset=['UUID студента'], keep='first')

# %%
df_1_sem_2.shape
# Out:
# (2281, 50)

# %%
df_1_sem_2["Код направления 1"] = np.nan
df_1_sem_2["Код направления 3"] = np.nan


df_1_sem_2[["Код направления 1", "Код направления 3"]] = df_1_sem_2["Код направления подготовки"].apply(
    lambda x: pd.Series({
        "Код направления 1": int(x.split(".")[0]),
        "Код направления 3": int(x.split(".")[2])
    })
)

# %%
df_1_sem_2["Часть1"].unique()
# Out:
# array([ 9, 11, 10, 27, 29])

# %%
df_1_sem_2.head(1)
# Out:
#                       UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0  studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
#
#    Балл за инд. достижения  Вид конкурса Тип олимпиады  \
# 0                        0  Особая квота           NaN
#
#    Категория конкурса БВИ Основа освоения (сокр.) Форма освоения  ...  \
# 0                       0                  бюджет          Очная  ...
#
#                       Название законченного уч. зав.  Год окончание уч. зав.  \
# 0  ГОСУДАРСТВЕННОЕ БЮДЖЕТНОЕПРОФЕССИОНАЛЬНОЕОБРАЗ...                    2023
#
#                     Тип документа об образовании Квалификация зак.уч.зав.  \
# 0  Диплом о среднем профессиональном образовании                      NaN
#
#   Специальность зак.уч.зав.                                    Льготы  \
# 0                       NaN  02 Лица из числа детей-сирот (до 23 лет)
#
#                   Документы подтв. льготы Новый таргет Код направления 1  \
# 0  31 Копия свидетельства о смерти матери     Активный                 9
#
#   Код направления 3
# 0                 4
#
# [1 rows x 45 columns]

# %%
df_1_sem_2 = df_1_sem_2.drop(columns=["Код направления подготовки", "Наименование напр. подготовки", "Образовательная программа"])

# %%
df_1_sem_2 = df_1_sem_2.drop(columns=["ЛН студента", "ЛН студента (архив)"])

# %%
df_1_sem_2["Основа освоения (сокр.)"].unique()
# Out:
# array(['бюджет', 'контракт'], dtype=object)

# %%
df_1_sem_2.columns
# Out:
# Index(['UUID студента', 'Приоритет', 'Cумма баллов испытаний', 'БВИ',
#        'Балл за инд. достижения', 'Вид конкурса', 'Тип олимпиады',
#        'Категория конкурса БВИ', 'Основа освоения (сокр.)', 'Форма освоения',
#        'Формирующее подразделение', 'Срок освоения', 'Уровень подготовки',
#        'Область образования', 'Целевик', 'Хоз. группа | Вкл. обучение',
#        'Нуждается в общежитии', 'Малоимущий', 'Слушатель',
#        'Иностранный абитуриент (МОН)', 'В архиве', 'Приказ об отчислении',
#        'Акад. отп. по сост. здор.', 'Акад. отп. по уходу за реб.',
#        'UUID персоны', 'Пол', 'Дата рождения', 'Гражданство',
#        'Адрес регистрации. Страна', 'Адрес регистрации. Область',
#        'Адрес регистрации. Город', 'Страна законченного уч. зав.',
#        'Регион законченного уч. зав.', 'Город законченного уч. зав.',
#        'Тип законченного уч. зав.', 'Название законченного уч. зав.',
#        'Год окончание уч. зав.', 'Тип документа об образовании',
#        'Квалификация зак.уч.зав.', 'Специальность зак.уч.зав.', 'Льготы',
#        'Документы подтв. льготы', 'Новый таргет', 'Код направления 1',
#        'Код направления 3'],
#       dtype='object')

# %%
df_1_sem_2["Регион законченного уч. зав."].isna().sum()
# Out:
# np.int64(1278)

# %%
col_to_drop = ["Формирующее подразделение", "Область образования", "Целевик", "Хоз. группа | Вкл. обучение", 
               "Малоимущий", "Слушатель", "В архиве", "Приказ об отчислении", "Акад. отп. по сост. здор.", "Акад. отп. по уходу за реб.", 
               "UUID персоны", "Адрес регистрации. Страна", "Адрес регистрации. Область", "Адрес регистрации. Город", "Страна законченного уч. зав.",
               "Название законченного уч. зав.", "Регион законченного уч. зав.", "Квалификация зак.уч.зав.", "Специальность зак.уч.зав.", "Документы подтв. льготы"]

current_col = df_1_sem_2.columns.tolist()
for col in col_to_drop:
    if col not in current_col:
        print(col)

# %%
df_1_sem_2 = df_1_sem_2.drop(columns=col_to_drop)

# %%
df_1_sem_2.head()
# Out:
#                         UUID студента  Приоритет  Cумма баллов испытаний  БВИ  \
# 0    studen195e3pg0000ok22fnqsr14o7ek          1                     205    0
# 28   studen195e3pg0000ok226fn6ou3b2v0          5                     236    0
# 56   studen195e3pg0000ok22cs2kmm1iuds          1                     154    0
# 85   studen195e3pg0000ok229rk4q8f5ru4          1                     209    0
# 115  studen195e3pg0000ok22a5a0pqm86ag          1                     196    0
#
#      Балл за инд. достижения   Вид конкурса Тип олимпиады  \
# 0                          0   Особая квота           NaN
# 28                         0  Целевая квота           NaN
# 56                         0  Целевая квота           NaN
# 85                         3   Особая квота           NaN
# 115                        0   Особая квота           NaN
#
#      Категория конкурса БВИ Основа освоения (сокр.) Форма освоения  ...  \
# 0                         0                  бюджет          Очная  ...
# 28                        0                  бюджет          Очная  ...
# 56                        0                  бюджет          Очная  ...
# 85                        0                  бюджет          Очная  ...
# 115                       0                  бюджет          Очная  ...
#
#      Дата рождения           Гражданство Город законченного уч. зав.  \
# 0       19.10.2002  Российская Федерация                  не указано
# 28      09.07.2005  Российская Федерация                       Серов
# 56      03.02.2005  Российская Федерация                     Чусовой
# 85      26.12.2005  Российская Федерация                       Пышма
# 115     17.10.2005  Российская Федерация                  не указано
#
#              Тип законченного уч. зав. Год окончание уч. зав.  \
# 0                              Колледж                   2023
# 28                            Техникум                   2023
# 56   Средняя общеобразовательная школа                   2023
# 85   Средняя общеобразовательная школа                   2023
# 115  Средняя общеобразовательная школа                   2023
#
#                       Тип документа об образовании  \
# 0    Диплом о среднем профессиональном образовании
# 28            Аттестат о среднем общем образовании
# 56            Аттестат о среднем общем образовании
# 85            Аттестат о среднем общем образовании
# 115          Аттестат о полном среднем образовании
#
#                                                 Льготы Новый таргет  \
# 0             02 Лица из числа детей-сирот (до 23 лет)     Активный
# 28                                                 NaN     Активный
# 56                                                 NaN     Активный
# 85                                    04 Дети-инвалиды     Активный
# 115  05 Лица из числа детей без попечения родителей...     Активный
#
#     Код направления 1  Код направления 3
# 0                   9                  4
# 28                  9                  4
# 56                  9                  4
# 85                  9                  4
# 115                 9                  4
#
# [5 rows x 25 columns]

# %%
df_1_sem_2.to_csv('../../data/datasets/dataset_1sem_4.csv', sep=';', index=False, encoding='utf-8-sig')
